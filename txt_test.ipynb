# %%
import re
def get_text_ls_id_ls(data_path):
    pat = re.compile(r'[\da-z]+\.txt.ann')
    with open(data_path, 'r') as rf:
        lines = rf.readlines()
    text_ls = []
    id_shared_ls = []
    for line in lines:
        text_ls.append(''.join(line.split('\t')[1].split(' ')))
        id_shared_ls.append(pat.findall(line.split('\t')[0])[0].replace('.txt.ann', ''))
    print(len(text_ls), len(id_shared_ls))
    return text_ls, id_shared_ls

# %%
from seqeval.metrics import classification_report
y_true = ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'B-PER', 'I-PER', 'B-MISC']
y_pred = ['O', 'O', 'B-MISC', 'I-MISC', 'B-MISC', 'I-MISC', 'O', 'B-PER', 'I-PER', 'B-MISC']
print(classification_report(y_true, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#        MISC       0.33      0.50      0.40         2
#         PER       1.00      1.00      1.00         1
#
# avg / total       0.56      0.67      0.60         3

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/imaging_report/800_210_random/test.txt', 'output/imaging_report/800_210_random/test_predictions.txt', 'imaging_report.json')
# Out:
# 0.9898491975225158
#                precision    recall  f1-score   support
#
# Hospital_Name       0.97      0.99      0.98       198
#    Check_Part       0.83      0.94      0.88       216
#   Report_Date       0.88      0.93      0.90       221
#          Name       0.95      0.99      0.97       210
#    Check_Date       0.87      0.98      0.92       153
#    Conclusion       0.82      0.95      0.88       199
#   Description       0.82      0.92      0.87       210
#    Check_Type       0.85      0.84      0.84       192
#
#   avg / total       0.87      0.94      0.91      1599
#
# 1479 1598 1622
# 1479 1614 1630
# 210
# ######### pred || text #########
# category: Name                	 correct: 208  	 pred: 216  	 gold: 210  	 precision: 0.9585	 f1: 0.9743
# category: Hospital_Name       	 correct: 196  	 pred: 202  	 gold: 198  	 precision: 0.9655	 f1: 0.9776
# category: Check_Date          	 correct: 150  	 pred: 157  	 gold: 153  	 precision: 0.9494	 f1: 0.9647
# ...

# %%
from IE_evaluation_utils import *
# _, ls = get_text_ls_id_ls('/data/maojingwei/imaging_report/800_210/all_210.tsv')
evaluate('/data/maojingwei/imaging_report/800_210/test.txt', 'output/imaging_report/800_210/test_predictions.txt', 'imaging_report.json')
# Out:
# 0.9866895208621863
#                precision    recall  f1-score   support
#
#   Description       0.89      0.91      0.90       207
#    Check_Date       0.83      0.95      0.89       154
#    Check_Part       0.81      0.91      0.85       212
#    Conclusion       0.92      1.00      0.95       209
# Hospital_Name       0.95      0.99      0.97       191
#          Name       0.94      0.96      0.95       209
#   Report_Date       0.88      0.95      0.91       237
#    Check_Type       0.77      0.76      0.76       178
#
#   avg / total       0.88      0.93      0.90      1597
#
# 1474 1578 1594
# 1474 1596 1603
# 210
# ######### pred || text #########
# category: Name                	 correct: 201  	 pred: 209  	 gold: 209  	 precision: 0.9571	 f1: 0.9595
# category: Hospital_Name       	 correct: 190  	 pred: 193  	 gold: 191  	 precision: 0.9794	 f1: 0.9870
# category: Check_Date          	 correct: 147  	 pred: 162  	 gold: 153  	 precision: 0.9018	 f1: 0.9305
# ...

# %%
from IE_evaluation_utils import *
_, ls = get_text_ls_id_ls('/data/maojingwei/xingchengdan_3code/APR22/all_236.tsv')
# evaluate('/data/maojingwei/xingchengdan_3code/APR22/augment/test.txt', 'output/20200423/test_predictions.txt', ls)
# evaluate('/data/maojingwei/xingchengdan_3code/APR22/test.txt', 'output/20200422/test_predictions.txt', ls)
# evaluate('/data/maojingwei/xingchengdan_3code/APR22/concat_augment/test.txt', 'output/20200429/test_predictions.txt', ls)
evaluate('/data/maojingwei/xingchengdan_3code/APR30/augment/test.txt', 'output/20200430/test_predictions.txt', 'xingchengdan_3code.json', ls)
# Out:
# 236 236
# 0.9739829844359087
#                   precision    recall  f1-score   support
#
#          Oil_Fee       0.43      0.57      0.49       153
#      Develop_Fee       0.46      0.56      0.50       142
#       Ticket_Fee       0.50      0.60      0.55       192
#        Other_Fee       0.60      0.74      0.66       114
#      Flight_Date       0.88      0.90      0.89       239
#             Name       0.77      0.86      0.81       223
#      Destination       0.87      0.90      0.88       251
#           Origin       0.84      0.86      0.85       202
# Destination_Code       0.92      0.94      0.93       242
#      Origin_Code       0.86      0.84      0.85       254
#        Total_Fee       0.46      0.53      0.49       183
#    Flight_Number       0.73      0.72      0.72       286
#
#      avg / total       0.73      0.77      0.75      2481
#
# 1862 2479 2475
# 1862 2531 2610
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/boardcards_keepempty/1503_288/all_288.tsv')
evaluate('/data/maojingwei/boardcards_keepempty/1503_288/test.txt', 'output/boardcards_keepempty/1503_288/test_predictions.txt', 'boardcards.json', id_ls)
# Out:
# 288 288
# 0.9698772794852132
#                 precision    recall  f1-score   support
#
#        Name_PY       0.60      0.77      0.68       342
#         Origin       0.40      0.37      0.38        93
# Destination_PY       0.37      0.67      0.48       273
#      Origin_PY       0.19      0.19      0.19       116
#  Flight_Number       0.78      0.92      0.84       461
#    Flight_Date       0.73      0.90      0.81       415
#    Destination       0.54      0.69      0.61       186
#           Name       0.72      0.80      0.76        95
#
#    avg / total       0.61      0.76      0.67      1981
#
# 1269 1744 1705
# 1269 2038 2033
# ['O7MAY@#07MAY@#07MAY', 'O7MAY@#07MAY@#07MAY', '07MAY', 'CZ6083@#CZ6083@#CZ6083', 'CZ6083@#CZ6083@#CZ6083', 'CZ6083', '', '', '', 'LONG/Q+@#LONG/QIJIEMR@#LONG/QIJIEMRTIM', 'LONG/Q+@#LONG/QIJIEMR@#LONG/QIJIEMRTIME', 'LONG/QIJIEMR', '曼谷@#曼谷', '曼谷@#曼谷', '曼谷', 'BANGKOK', 'BANGKOK@#BANGKOK', 'MANGKOK', '', '', '', '', '', '']
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/boardcards_keepempty/1503_288/all_288.tsv')
evaluate('/data/maojingwei/boardcards_keepempty/1503_288/augment/test.txt', 'output/boardcards_keepempty/1503_288_augment/test_predictions.txt', 'boardcards.json', id_ls)
# Out:
# 288 288
# 0.9787377427819188
#                 precision    recall  f1-score   support
#
#        Name_PY       0.80      0.85      0.82       342
#         Origin       0.86      0.78      0.82        93
# Destination_PY       0.72      0.79      0.75       273
#      Origin_PY       0.75      0.78      0.77       116
#  Flight_Number       0.89      0.92      0.91       461
#    Flight_Date       0.88      0.94      0.91       415
#    Destination       0.85      0.85      0.85       186
#           Name       0.78      0.91      0.84        95
#
#    avg / total       0.83      0.87      0.85      1981
#
# 1461 1718 1705
# 1461 2022 2033
# ['O7MAY@#07MAY@#07MAY', 'O7MAY@#07MAY@#07MAY', '07MAY', 'CZ6083@#CZ6083@#CZ6083', 'CZ6083@#CZ6083@#CZ6083', 'CZ6083', '', '', '', 'LONG/Q+@#LONG/QIJIEMR@#LONG/QIJIEMRTIME', 'LONG/Q+@#LONG/QIJIEMR@#LONG/QIJIEMRTIME', 'LONG/QIJIEMR', '曼谷@#曼谷', '曼谷@#曼谷', '曼谷', 'BANGKOK@#BANGKOK', 'BANGKOK@#BANGKOK', 'MANGKOK', '', '', '', '', '', '']
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288/all_288.tsv')
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288/augment/test.txt', 'output/boardcards/1500_288_augment/test_predictions.txt', 'boardcards.json', id_ls)
# Out:
# 288 288
# 0.9715824288191511
#                 precision    recall  f1-score   support
#
#      Origin_PY       0.56      0.65      0.60       116
#  Flight_Number       0.86      0.89      0.87       464
# Destination_PY       0.59      0.70      0.64       275
#    Flight_Date       0.85      0.91      0.88       418
#        Name_PY       0.67      0.76      0.71       345
#    Destination       0.84      0.84      0.84       188
#           Name       0.79      0.91      0.84        95
#         Origin       0.85      0.76      0.80        93
#
#    avg / total       0.76      0.82      0.79      1994
#
# 1377 1731 1705
# 1377 2031 2033
# ['O7MAY@#07MAY@#07MAY', 'O7MAY@#07MAY@#07MAY', '07MAY', 'CZ6083@#CZ6083@#CZ6083', 'CZ6083@#CZ6083@#CZ6083', 'CZ6083', '', '', '', 'LONG/Q+@#LONG/QIJIEMR@#LONG/QIJIEMR', 'LONG/Q+@#LONG/QIJIEMR@#LONG/QIJIEMRTIME', 'LONG/QIJIEMR', '曼谷@#曼谷', '曼谷@#曼谷', '曼谷', 'BANGKOK@#BANGKOK', 'BANGKOK@#BANGKOK', 'MANGKOK', '', '', '', '', '', '']
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288_random/test.txt', 'output/boardcards/1500_288_random_correct_epoch5/test_predictions.txt', 'boardcards.json')
# Out:
# 0.968830325233072
#                 precision    recall  f1-score   support
#
#        Name_PY       0.56      0.68      0.61       330
#         Origin       0.65      0.56      0.60        91
# Destination_PY       0.40      0.59      0.47       258
#    Destination       0.62      0.79      0.70       165
#    Flight_Date       0.71      0.82      0.76       396
#  Flight_Number       0.72      0.85      0.78       429
#      Origin_PY       0.39      0.49      0.43       109
#           Name       0.78      0.96      0.86        99
#
#    avg / total       0.62      0.74      0.67      1877
#
# 1255 1760 1686
# 1255 1956 1908
# 288
# ######### pred || text #########
# category: Flight_Date         	 correct: 273  	 pred: 357  	 gold: 322  	 precision: 0.7626	 f1: 0.8032
# category: Flight_Number       	 correct: 284  	 pred: 368  	 gold: 343  	 precision: 0.7696	 f1: 0.7980
# category: Name                	 correct: 88   	 pred: 104  	 gold: 93   	 precision: 0.8381	 f1: 0.8891
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288_random/test.txt', 'output/boardcards/1500_288_random_reinit1_epoch5/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9713358363128992
#                 precision    recall  f1-score   support
#
#        Name_PY       0.62      0.74      0.67       330
#         Origin       0.59      0.56      0.58        91
# Destination_PY       0.45      0.61      0.52       258
#    Destination       0.66      0.83      0.74       165
#    Flight_Date       0.68      0.81      0.74       396
#  Flight_Number       0.73      0.86      0.79       429
#      Origin_PY       0.48      0.53      0.51       109
#           Name       0.78      0.91      0.84        99
#
#    avg / total       0.64      0.76      0.69      1877
#
# 1267 1763 1686
# 1267 1958 1908
# 288
# ######### pred || text #########
# category: Flight_Date         	 correct: 268  	 pred: 361  	 gold: 322  	 precision: 0.7403	 f1: 0.7839
# category: Flight_Number       	 correct: 287  	 pred: 369  	 gold: 343  	 precision: 0.7757	 f1: 0.8053
# category: Name                	 correct: 84   	 pred: 100  	 gold: 93   	 precision: 0.8317	 f1: 0.8665
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288_random/test.txt', 'output/boardcards/1500_288_random_reinit1/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9632211592358719
#                 precision    recall  f1-score   support
#
#        Name_PY       0.48      0.63      0.54       330
# Destination_PY       0.27      0.40      0.32       258
#    Flight_Date       0.61      0.75      0.67       396
#  Flight_Number       0.69      0.82      0.75       429
#           Name       0.72      0.91      0.80        99
#      Origin_PY       0.23      0.30      0.26       109
#    Destination       0.51      0.68      0.58       165
#         Origin       0.46      0.45      0.46        91
#
#    avg / total       0.53      0.66      0.58      1877
#
# 1098 1742 1686
# 1098 1914 1908
# 288
# ######### pred || text #########
# category: Flight_Date         	 correct: 248  	 pred: 368  	 gold: 322  	 precision: 0.6721	 f1: 0.7181
# category: Flight_Number       	 correct: 261  	 pred: 359  	 gold: 343  	 precision: 0.7250	 f1: 0.7429
# category: Name                	 correct: 83   	 pred: 103  	 gold: 93   	 precision: 0.7981	 f1: 0.8431
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288_random/test.txt', 'output/boardcards/1500_288_random_occam/test_predictions.txt', 'boardcards.json')
# Out:
# 0.8736306355134493
#                 precision    recall  f1-score   support
#
# Destination_PY       0.00      0.00      0.00       258
#        Name_PY       0.00      0.00      0.00       330
#    Destination       0.00      0.00      0.00       165
#      Origin_PY       0.00      0.00      0.00       109
#           Name       0.00      0.00      0.00        99
#  Flight_Number       0.00      0.00      0.00       429
#         Origin       0.00      0.00      0.00        91
#    Flight_Date       0.00      0.00      0.00       396
#
#    avg / total       0.00      0.00      0.00      1877
#
# 0 0 1686
# 0 0 1908
# 288
# ######### pred || text #########
# category: Flight_Date         	 correct: 0    	 pred: 0    	 gold: 322  	 precision: 0.0000	 f1: 0.0000
# category: Flight_Number       	 correct: 0    	 pred: 0    	 gold: 343  	 precision: 0.0000	 f1: 0.0000
# category: Name                	 correct: 0    	 pred: 0    	 gold: 93   	 precision: 0.0000	 f1: 0.0000
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288_random/test.txt', 'output/boardcards/1500_288_random_correct_bias/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9626189060893942
#                 precision    recall  f1-score   support
#
# Destination_PY       0.27      0.46      0.34       258
#        Name_PY       0.46      0.59      0.52       330
#    Destination       0.51      0.66      0.58       165
#      Origin_PY       0.23      0.27      0.25       109
#           Name       0.80      0.91      0.85        99
#  Flight_Number       0.67      0.81      0.73       429
#         Origin       0.42      0.38      0.40        91
#    Flight_Date       0.58      0.74      0.65       396
#
#    avg / total       0.52      0.65      0.57      1877
#
# 1103 1740 1686
# 1103 1916 1908
# 288
# ######### pred || text #########
# category: Flight_Date         	 correct: 251  	 pred: 374  	 gold: 322  	 precision: 0.6693	 f1: 0.7205
# category: Flight_Number       	 correct: 267  	 pred: 378  	 gold: 343  	 precision: 0.7045	 f1: 0.7399
# category: Name                	 correct: 83   	 pred: 95   	 gold: 93   	 precision: 0.8646	 f1: 0.8789
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288_random/test.txt', 'output/boardcards/1500_288_random/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9626189060893942
#                 precision    recall  f1-score   support
#
# Destination_PY       0.27      0.46      0.34       258
#    Destination       0.51      0.66      0.58       165
#    Flight_Date       0.58      0.74      0.65       396
#  Flight_Number       0.67      0.81      0.73       429
#      Origin_PY       0.23      0.27      0.25       109
#           Name       0.80      0.91      0.85        99
#        Name_PY       0.46      0.59      0.52       330
#         Origin       0.42      0.38      0.40        91
#
#    avg / total       0.52      0.65      0.57      1877
#
# 1103 1740 1686
# 1103 1916 1908
# 288
# ######### pred || text #########
# category: Flight_Date         	 correct: 251  	 pred: 374  	 gold: 322  	 precision: 0.6693	 f1: 0.7205
# category: Flight_Number       	 correct: 267  	 pred: 378  	 gold: 343  	 precision: 0.7045	 f1: 0.7399
# category: Name                	 correct: 83   	 pred: 95   	 gold: 93   	 precision: 0.8646	 f1: 0.8789
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/boarding_cards_annotated/withsecond/1199_589/all_589.tsv')
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1199_589/augment/test.txt', 'output/boardcards/1199_589_augment/test_predictions.txt', 'boardcards.json', id_ls)
# Out:
# 589 589
# 0.9694866139013825
#                 precision    recall  f1-score   support
#
#           Name       0.68      0.89      0.77       175
#    Flight_Date       0.78      0.88      0.83       849
# Destination_PY       0.55      0.64      0.59       562
#        Name_PY       0.65      0.76      0.70       680
#    Destination       0.80      0.83      0.82       338
#      Origin_PY       0.57      0.67      0.61       257
#  Flight_Number       0.83      0.89      0.86       903
#         Origin       0.79      0.86      0.82       189
#
#    avg / total       0.72      0.81      0.76      3953
#
# 2745 3591 3467
# 2745 4145 4041
# ['2ODEC', '2ODEC', '20DEC', 'CZ2776', 'CZ2776', 'CZ2776', '', '', '', 'CHEN/SUZHEN', 'CHEN/SUZHEN', 'CHEN/SUZHEN', '武汉', '武汉', '武汉', 'WUHAN', 'WUHAN', 'WUHAN', '神农架', '神农架', '神农架', 'SHENNONGJI', 'SHENNONGJI', 'SHENNONGJI']
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288/all_288.tsv')
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288/augment/test.txt', 'output/boardcards/1500_288_augment/test_predictions.txt', 'boardcards.json', id_ls)
# Out:
# 288 288
# 0.9715824288191511
#                 precision    recall  f1-score   support
#
#        Name_PY       0.67      0.76      0.71       345
#      Origin_PY       0.56      0.65      0.60       116
#    Flight_Date       0.85      0.91      0.88       418
#    Destination       0.84      0.84      0.84       188
#  Flight_Number       0.86      0.89      0.87       464
# Destination_PY       0.59      0.70      0.64       275
#         Origin       0.85      0.76      0.80        93
#           Name       0.79      0.91      0.84        95
#
#    avg / total       0.76      0.82      0.79      1994
#
# 1377 1731 1705
# 1377 2031 2033
# 288
# Flight_Date: 0, 288, 0.0000  Flight_Number: 0, 288, 0.0000  Name: 0, 288, 0.0000  Name_PY: 0, 288, 0.0000  Destination: 0, 288, 0.0000  Destination_PY: 0, 288, 0.0000  Origin: 0, 288, 0.0000  Origin_PY: 0, 288, 0.0000  overall_short: 0, 2304, 0.0000
#
# ######### pred || text #########
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/1500_288/test.txt', 'output/boardcards/1500_288/test_predictions.txt', 'boardcards.json')
# Out:
# 0.957620489525204
# 1067 1740 1705
# 1067 1983 2033
# ######### pred || text #########
# category: Flight_Date         	 correct: 237  	 pred: 385  	 gold: 315  	 precision: 0.6140	 f1: 0.6765
# category: Flight_Number       	 correct: 281  	 pred: 365  	 gold: 348  	 precision: 0.7678	 f1: 0.7874
# category: Name                	 correct: 62   	 pred: 81   	 gold: 87   	 precision: 0.7561	 f1: 0.7355
# category: Name_PY             	 correct: 182  	 pred: 320  	 gold: 322  	 precision: 0.5670	 f1: 0.5668
# category: Destination         	 correct: 109  	 pred: 177  	 gold: 173  	 precision: 0.6124	 f1: 0.6221
# category: Destination_PY      	 correct: 122  	 pred: 285  	 gold: 254  	 precision: 0.4266	 f1: 0.4528
# category: Origin              	 correct: 42   	 pred: 71   	 gold: 91   	 precision: 0.5833	 f1: 0.5190
# category: Origin_PY           	 correct: 32   	 pred: 56   	 gold: 115  	 precision: 0.5614	 f1: 0.3776
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/test.txt', 'output/20200525b/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9695164915390687
# 2750 3549 3467
# 2750 4102 4041
# ######### pred || text #########
# category: Flight_Date         	 correct: 579  	 pred: 712  	 gold: 662  	 precision: 0.8121	 f1: 0.8423
# category: Flight_Number       	 correct: 596  	 pred: 690  	 gold: 689  	 precision: 0.8625	 f1: 0.8639
# category: Name                	 correct: 144  	 pred: 191  	 gold: 164  	 precision: 0.7500	 f1: 0.8093
# category: Name_PY             	 correct: 495  	 pred: 659  	 gold: 647  	 precision: 0.7500	 f1: 0.7576
# category: Destination         	 correct: 261  	 pred: 326  	 gold: 318  	 precision: 0.7982	 f1: 0.8096
# category: Destination_PY      	 correct: 343  	 pred: 531  	 gold: 541  	 precision: 0.6447	 f1: 0.6397
# category: Origin              	 correct: 163  	 pred: 199  	 gold: 187  	 precision: 0.8150	 f1: 0.8427
# category: Origin_PY           	 correct: 169  	 pred: 241  	 gold: 259  	 precision: 0.6983	 f1: 0.6754
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/test.txt', 'output/20200525a_bert/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9715541068061863
# 2790 3609 3467
# 2790 4171 4041
# ######### pred || text #########
# category: Flight_Date         	 correct: 572  	 pred: 694  	 gold: 662  	 precision: 0.8230	 f1: 0.8431
# category: Flight_Number       	 correct: 617  	 pred: 705  	 gold: 689  	 precision: 0.8739	 f1: 0.8847
# category: Name                	 correct: 146  	 pred: 206  	 gold: 164  	 precision: 0.7053	 f1: 0.7873
# category: Name_PY             	 correct: 488  	 pred: 678  	 gold: 647  	 precision: 0.7187	 f1: 0.7362
# category: Destination         	 correct: 268  	 pred: 323  	 gold: 318  	 precision: 0.8272	 f1: 0.8351
# category: Destination_PY      	 correct: 366  	 pred: 562  	 gold: 541  	 precision: 0.6501	 f1: 0.6633
# category: Origin              	 correct: 163  	 pred: 191  	 gold: 187  	 precision: 0.8490	 f1: 0.8605
# category: Origin_PY           	 correct: 170  	 pred: 250  	 gold: 259  	 precision: 0.6773	 f1: 0.6673
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/test.txt', 'output/20200524c/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9715541068061863
# 2790 3609 3467
# 2790 4171 4041
# ######### pred || text #########
# category: Flight_Date         	 correct: 572  	 pred: 694  	 gold: 662  	 precision: 0.8230	 f1: 0.8431
# category: Flight_Number       	 correct: 617  	 pred: 705  	 gold: 689  	 precision: 0.8739	 f1: 0.8847
# category: Name                	 correct: 146  	 pred: 206  	 gold: 164  	 precision: 0.7053	 f1: 0.7873
# category: Name_PY             	 correct: 488  	 pred: 678  	 gold: 647  	 precision: 0.7187	 f1: 0.7362
# category: Destination         	 correct: 268  	 pred: 323  	 gold: 318  	 precision: 0.8272	 f1: 0.8351
# category: Destination_PY      	 correct: 366  	 pred: 562  	 gold: 541  	 precision: 0.6501	 f1: 0.6633
# category: Origin              	 correct: 163  	 pred: 191  	 gold: 187  	 precision: 0.8490	 f1: 0.8605
# category: Origin_PY           	 correct: 170  	 pred: 250  	 gold: 259  	 precision: 0.6773	 f1: 0.6673
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/test.txt', 'output/20200524b/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9526982699718572
# 1856 3221 3467
# 1856 3643 4041
# ######### pred || text #########
# category: Flight_Date         	 correct: 462  	 pred: 736  	 gold: 662  	 precision: 0.6269	 f1: 0.6607
# category: Flight_Number       	 correct: 519  	 pred: 729  	 gold: 689  	 precision: 0.7110	 f1: 0.7317
# category: Name                	 correct: 57   	 pred: 69   	 gold: 164  	 precision: 0.8143	 f1: 0.4911
# category: Name_PY             	 correct: 311  	 pred: 578  	 gold: 647  	 precision: 0.5371	 f1: 0.5078
# category: Destination         	 correct: 215  	 pred: 383  	 gold: 318  	 precision: 0.5599	 f1: 0.6130
# category: Destination_PY      	 correct: 210  	 pred: 597  	 gold: 541  	 precision: 0.3512	 f1: 0.3693
# category: Origin              	 correct: 81   	 pred: 127  	 gold: 187  	 precision: 0.6328	 f1: 0.5164
# category: Origin_PY           	 correct: 1    	 pred: 2    	 gold: 259  	 precision: 0.3333	 f1: 0.0150
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/xingchengdan_3code/APR22/all_236.tsv')
evaluate('/data/maojingwei/xingchengdan_3code/APR30/augment/test.txt', 'output/20200430_reproduce/test_predictions.txt', 'xingchengdan_3code.json', id_ls)
# Out:
# 236 236
# 0.9739829844359087
#                   precision    recall  f1-score   support
#
#        Total_Fee       0.46      0.53      0.49       183
#      Destination       0.87      0.90      0.88       251
#      Origin_Code       0.86      0.84      0.85       254
#           Origin       0.84      0.86      0.85       202
#    Flight_Number       0.73      0.72      0.72       286
#             Name       0.77      0.86      0.81       223
#        Other_Fee       0.60      0.74      0.66       114
#          Oil_Fee       0.43      0.57      0.49       153
#      Flight_Date       0.88      0.90      0.89       239
# Destination_Code       0.92      0.94      0.93       242
#      Develop_Fee       0.46      0.56      0.50       142
#       Ticket_Fee       0.50      0.60      0.55       192
#
#      avg / total       0.73      0.77      0.75      2481
#
# 1862 2479 2475
# 1862 2531 2610
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/xingchengdan_3code/APR22/all_236.tsv')
evaluate('/data/maojingwei/xingchengdan_3code/APR30/test.txt', 'output/20200524a/test_predictions.txt', 'xingchengdan_3code.json', id_ls)
# Out:
# 236 236
# 0.9676727635788808
#                   precision    recall  f1-score   support
#
#        Other_Fee       0.34      0.54      0.41       114
#      Flight_Date       0.71      0.77      0.74       239
#             Name       0.61      0.72      0.66       223
#       Ticket_Fee       0.38      0.50      0.43       192
#    Flight_Number       0.38      0.51      0.44       286
#      Develop_Fee       0.20      0.32      0.24       142
#        Total_Fee       0.41      0.55      0.47       183
#           Origin       0.64      0.69      0.67       202
# Destination_Code       0.70      0.82      0.76       242
#      Origin_Code       0.65      0.68      0.67       254
#      Destination       0.66      0.79      0.72       251
#          Oil_Fee       0.19      0.30      0.23       153
#
#      avg / total       0.52      0.62      0.56      2481
#
# 1432 2057 2475
# 1432 2111 2610
# ...

# %%
from IE_evaluation_utils import *
_, id_ls = get_text_ls_id_ls('/data/maojingwei/discharge_records_new/keep_newline/3/all_448.tsv')
evaluate('/data/maojingwei/discharge_records_new/keep_newline/3/test.txt', 'output/discharge_records/keep_newline3/test_predictions.txt', 'discharge_records.json')#, id_ls)
# Out:
# 448 448
# 0.9363667531071241
#                   precision    recall  f1-score   support
#
#             Name       0.91      0.98      0.95       587
#          ad_diag       0.43      0.64      0.51       275
#   Admission_Date       0.91      0.97      0.94       333
#   Discharge_Date       0.85      0.93      0.89       321
# Admission_Number       0.86      0.93      0.89       396
#    Hospital_Name       0.90      0.97      0.93       421
#       Department       0.62      0.67      0.65       412
#         dis_diag       0.51      0.66      0.58       273
#         dis_note       0.49      0.74      0.59       100
#          ad_main       0.17      0.37      0.23       298
#         dis_situ       0.38      0.59      0.46       102
#
#      avg / total       0.70      0.81      0.75      3518
#
# 2382 2941 3853
# 2382 3184 4088
# 448
# ######### pred || text #########
# category: Discharge_Date      	 correct: 299  	 pred: 325  	 gold: 321  	 precision: 0.9172	 f1: 0.9244
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/discharge_records_new/correct_test_disdate_addate/test.txt', 'output/discharge_records/keep_newline2/test_predictions.txt', 'discharge_records.json')
# Out:
# 0.9296424965430848
#                   precision    recall  f1-score   support
#
# Admission_Number       0.93      0.96      0.94       394
#             Name       0.90      0.98      0.94       592
#    Hospital_Name       0.90      0.93      0.92       446
#         dis_situ       0.18      0.38      0.25       111
#          ad_diag       0.52      0.71      0.60       300
#   Admission_Date       0.89      0.94      0.91       361
#          ad_main       0.08      0.13      0.10       335
#   Discharge_Date       0.92      0.95      0.94       352
#       Department       0.55      0.68      0.61       422
#         dis_diag       0.48      0.59      0.53       270
#         dis_note       0.26      0.51      0.34       103
#
#      avg / total       0.69      0.77      0.73      3686
#
# 2461 3124 4204
# 2461 3395 4435
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/discharge_records_new/keep_newline/2/test.txt', 'output/discharge_records/keep_newline2/test_predictions.txt', 'discharge_records.json')
# Out:
# 0.9281263901005075
#                   precision    recall  f1-score   support
#
# Admission_Number       0.93      0.94      0.93       403
#         dis_diag       0.48      0.58      0.53       273
#          ad_diag       0.52      0.71      0.60       300
#   Admission_Date       0.85      0.92      0.89       357
#         dis_note       0.26      0.51      0.34       103
#    Hospital_Name       0.90      0.93      0.92       446
#             Name       0.90      0.98      0.94       593
#          ad_main       0.08      0.13      0.10       335
#   Discharge_Date       0.87      0.93      0.90       341
#       Department       0.55      0.68      0.61       422
#         dis_situ       0.18      0.38      0.25       111
#
#      avg / total       0.68      0.77      0.72      3684
#
# 2432 3124 4202
# 2432 3395 4433
# 448
# pred Discharge_Date 0
# pred_rule Discharge_Date 0
# pred Admission_Number 0
# pred_rule Admission_Number 0
# pred Hospital_Name 0
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/discharge_records_new/keep_newline/test.txt', 'output/discharge_records/keep_newline/test_predictions.txt', 'discharge_records.json')
# Out:
# 0.9285061007708247
#                   precision    recall  f1-score   support
#
#          ad_main       0.08      0.13      0.10       335
#         dis_situ       0.20      0.38      0.26       111
#             Name       0.91      0.99      0.94       593
#          ad_diag       0.53      0.71      0.61       300
#    Hospital_Name       0.90      0.94      0.92       446
# Admission_Number       0.92      0.93      0.93       403
#   Discharge_Date       0.87      0.93      0.90       341
#         dis_diag       0.48      0.57      0.52       273
#   Admission_Date       0.86      0.91      0.88       357
#         dis_note       0.25      0.50      0.33       103
#       Department       0.55      0.68      0.61       422
#
#      avg / total       0.68      0.76      0.72      3684
#
# 2425 3137 4202
# 2425 3404 4433
# 448
# pred Discharge_Date 0
# pred_rule Discharge_Date 0
# pred Admission_Number 0
# pred_rule Admission_Number 0
# pred Hospital_Name 0
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/discharge_records_new/keep_space/test.txt', 'output/discharge_records/keep_space/test_predictions.txt', 'discharge_records.json')
# Out:
# 0.9299884834518307
#                   precision    recall  f1-score   support
#
#         dis_diag       0.44      0.55      0.49       281
#          ad_main       0.16      0.32      0.22       298
#   Discharge_Date       0.86      0.93      0.89       321
#    Hospital_Name       0.79      0.87      0.83       422
#         dis_note       0.41      0.61      0.49       103
#       Department       0.60      0.67      0.64       412
#   Admission_Date       0.84      0.95      0.89       333
#          ad_diag       0.42      0.60      0.49       275
# Admission_Number       0.83      0.90      0.86       396
#             Name       0.90      0.98      0.94       587
#         dis_situ       0.28      0.59      0.38       109
#
#      avg / total       0.67      0.77      0.71      3537
#
# 2287 2979 3842
# 2287 3219 4075
# 448
# pred Discharge_Date 0
# pred_rule Discharge_Date 0
# pred Admission_Number 0
# pred_rule Admission_Number 0
# pred Hospital_Name 0
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/discharge_records_new/test.txt', 'output/20200523/test_predictions.txt', 'discharge_records.json')
# Out:
# 0.9268314906624778
#                   precision    recall  f1-score   support
#
#         dis_diag       0.36      0.49      0.41       282
#   Admission_Date       0.82      0.94      0.88       333
#          ad_main       0.11      0.25      0.16       298
#             Name       0.90      0.98      0.94       588
#    Hospital_Name       0.79      0.86      0.82       422
# Admission_Number       0.84      0.90      0.87       396
#       Department       0.58      0.65      0.61       412
#          ad_diag       0.40      0.59      0.48       276
#   Discharge_Date       0.81      0.89      0.85       321
#         dis_situ       0.23      0.45      0.30       112
#         dis_note       0.44      0.60      0.51       111
#
#      avg / total       0.64      0.75      0.69      3551
#
# 2235 2895 3834
# 2235 3138 4067
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/augment/test.txt', 'output/debug3/checkpoint-5000/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9707626682033164
#                 precision    recall  f1-score   support
#
#  Flight_Number       0.86      0.89      0.88       903
#        Name_PY       0.71      0.78      0.74       680
# Destination_PY       0.61      0.66      0.64       562
#    Flight_Date       0.83      0.88      0.86       849
#    Destination       0.81      0.82      0.81       338
#         Origin       0.81      0.86      0.84       189
#      Origin_PY       0.64      0.68      0.66       257
#           Name       0.66      0.88      0.75       175
#
#    avg / total       0.76      0.82      0.79      3953
#
# 2778 3620 3467
# 2778 4182 4041
# 589
# pred Flight_Date 0
# pred_rule Flight_Date 0
# pred_rule Flight_Date 0
# pred Flight_Number 0
# pred_rule Flight_Number 0
# pred_rule Flight_Number 0
# pred Name 0
# pred_rule Name 0
# pred_rule Name 0
# pred Name_PY 0
# pred_rule Name_PY 0
# pred_rule Name_PY 0
# pred Destination 0
# pred_rule Destination 0
# pred_rule Destination 0
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/augment/test.txt', 'output/20200508_reproduce/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9704465804633532
#                 precision    recall  f1-score   support
#
# Destination_PY       0.56      0.64      0.60       562
#    Flight_Date       0.81      0.88      0.84       849
#        Name_PY       0.66      0.77      0.71       680
#      Origin_PY       0.55      0.67      0.60       257
#  Flight_Number       0.84      0.89      0.87       903
#    Destination       0.76      0.81      0.79       338
#         Origin       0.75      0.83      0.79       189
#           Name       0.64      0.88      0.74       175
#
#    avg / total       0.72      0.81      0.76      3953
#
# 2756 3580 3467
# 2756 4140 4041
# 589
# ######### pred || text #########
# category: Flight_Date         	 correct: 574  	 pred: 696  	 gold: 662  	 precision: 0.8235	 f1: 0.8448
# category: Flight_Number       	 correct: 600  	 pred: 692  	 gold: 689  	 precision: 0.8658	 f1: 0.8684
# category: Name                	 correct: 144  	 pred: 217  	 gold: 164  	 precision: 0.6606	 f1: 0.7542
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/augment/test.txt', 'output/20200503_reproduce/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9715541068061863
#                 precision    recall  f1-score   support
#
# Destination_PY       0.57      0.67      0.62       562
#    Flight_Date       0.80      0.88      0.84       849
#        Name_PY       0.66      0.76      0.71       680
#      Origin_PY       0.54      0.64      0.59       257
#  Flight_Number       0.85      0.91      0.88       903
#    Destination       0.79      0.84      0.82       338
#         Origin       0.79      0.85      0.82       189
#           Name       0.67      0.90      0.77       175
#
#    avg / total       0.73      0.82      0.77      3953
#
# 2790 3609 3467
# 2790 4171 4041
# 589
# ######### pred || text #########
# category: Flight_Date         	 correct: 572  	 pred: 694  	 gold: 662  	 precision: 0.8230	 f1: 0.8431
# category: Flight_Number       	 correct: 617  	 pred: 705  	 gold: 689  	 precision: 0.8739	 f1: 0.8847
# category: Name                	 correct: 146  	 pred: 206  	 gold: 164  	 precision: 0.7053	 f1: 0.7873
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data/maojingwei/boarding_cards_annotated/withsecond/test.txt', 'output/202003111550/test_predictions.txt', 'boardcards.json')
# Out:
# 0.9510824995939666
# 1784 3061 3467
# 1784 3458 4041
# ######### pred || text #########
# category: Flight_Date         	 correct: 445  	 pred: 709  	 gold: 662  	 precision: 0.6268	 f1: 0.6489
# category: Flight_Number       	 correct: 507  	 pred: 724  	 gold: 689  	 precision: 0.6993	 f1: 0.7173
# category: Name                	 correct: 73   	 pred: 85   	 gold: 164  	 precision: 0.8488	 f1: 0.5869
# category: Name_PY             	 correct: 274  	 pred: 478  	 gold: 647  	 precision: 0.5720	 f1: 0.4873
# category: Destination         	 correct: 218  	 pred: 381  	 gold: 318  	 precision: 0.5707	 f1: 0.6233
# category: Destination_PY      	 correct: 198  	 pred: 572  	 gold: 541  	 precision: 0.3455	 f1: 0.3560
# category: Origin              	 correct: 69   	 pred: 112  	 gold: 187  	 precision: 0.6106	 f1: 0.4626
# category: Origin_PY           	 correct: 0    	 pred: 0    	 gold: 259  	 precision: 0.0000	 f1: 0.0000
# ...

# %%
from IE_evaluation_utils import *
evaluate('/data2/zhuyiang/dataset/dataset_board_card/augment_name_loc/test.txt', 'output/202003111613/test_predictions.txt', 'boardcards.json')
# Out:
# 3362 4326 4183
# 3362 4854 4729
# > /data/maojingwei/entity_recognize_for_flight/IE_evaluation_utils.py(261)evaluate()
#     260     ipdb.set_trace()
# --> 261     cal_p_r_f1(pred_num, gold_num, correct_num)
#     262
#
# ipdb> c
# ######### pred || text #########
# category: Flight_Date         	 correct: 723  	 pred: 863  	 gold: 804  	 precision: 0.8368	 f1: 0.8670
# category: Flight_Number       	 correct: 753  	 pred: 858  	 gold: 837  	 precision: 0.8766	 f1: 0.8880
# category: Name                	 correct: 203  	 pred: 270  	 gold: 223  	 precision: 0.7491	 f1: 0.8220
# category: Name_PY             	 correct: 597  	 pred: 827  	 gold: 758  	 precision: 0.7210	 f1: 0.7530
# category: Destination         	 correct: 314  	 pred: 374  	 gold: 389  	 precision: 0.8373	 f1: 0.8222
# category: Destination_PY      	 correct: 403  	 pred: 627  	 gold: 617  	 precision: 0.6417	 f1: 0.6477
# ...

# %%
from IE_evaluation_utils import *
with open('/data/maojingwei/xingchengdan_annotated/Mar5/all_382.tsv', 'r') as rf:
    lines = rf.readlines()
import re
pat = re.compile(r'[\da-z].+')
ls = []
for line in lines:
    ls.extend(pat.findall(line.split('\t')[0].replace('.txt.ann', '')))
evaluate('/data/maojingwei/xingchengdan_annotated/Mar5/augment/test.txt', 'output/202003131520/test_predictions.txt', 'xingchengdan.json',  ls)
# Out:
# 1930 3249 3601
# 1930 3321 3666
# ######### pred || text #########
# category: Name                	 correct: 295  	 pred: 300  	 gold: 313  	 f1: 0.9610
# category: Flight_Number       	 correct: 136  	 pred: 145  	 gold: 155  	 f1: 0.9041
# category: Flight_Date         	 correct: 295  	 pred: 297  	 gold: 300  	 f1: 0.9866
# category: Origin              	 correct: 124  	 pred: 136  	 gold: 138  	 f1: 0.9022
# category: Destination         	 correct: 120  	 pred: 126  	 gold: 145  	 f1: 0.8830
# category: Ticket_Fee          	 correct: 72   	 pred: 144  	 gold: 143  	 f1: 0.5017
# category: Develop_Fee         	 correct: 49   	 pred: 72   	 gold: 73   	 f1: 0.6734
# category: Oil_Fee             	 correct: 88   	 pred: 103  	 gold: 121  	 f1: 0.7835
# category: Other_Fee           	 correct: 132  	 pred: 143  	 gold: 215  	 f1: 0.7367
# category: Total_Fee           	 correct: 34   	 pred: 100  	 gold: 118  	 f1: 0.3139
# ...

# %%
from IE_evaluation_utils import *
entity_lls1, _ = extract_entity('output/20200423/test_predictions.txt')

# %%
print(set(entity_lls1[0]))
# Out:
# {'Total_Fee+=+1830.00', 'Origin+=+HPG', 'Destination+=+上海浦东', 'Flight_Date+=+2019-0624', 'Develop_Fee+=+40.00', 'Flight_Number+=+MU537', 'Name+=+QIN/FEL', 'Flight_Number+=+FM84', 'Ticket_Fee+=+1200.00', 'Destination+=+曼谷口', 'Origin_Code+=+HPGT', 'Destination+=+中院'}

# %%
entity_lls2 = [['Name+=+QIN/FEL', 'Flight_Number+=+MU537', 'Flight_Number+=+FM84', 'Flight_Number+=+MU537', 'Flight_Number+=+FM84', 'Flight_Date+=+24JUN', 'Origin+=+HPG', 'Destination+=+上海浦东', 'Destination+=+中院', 'Destination+=+曼谷口', 'Ticket_Fee+=+1200.00', 'Develop_Fee+=+40.00', 'Total_Fee+=+1830.00', 'Origin_Code+=+HPGT'], ['Name+=+杨帅杰', 'Flight_Number+=+GZ3881', 'Flight_Date+=+2019-04-18', 'Origin+=+珠海', 'Destination+=+杭州', 'Ticket_Fee+=+NY1310.0', 'Oil_Fee+=+50.', 'Total_Fee+=+1360.0', 'Origin_Code+=+ZUH', 'Destination_Code+=+HGH'], ['Name+=+张思睿', 'Flight_Number+=+8L9628', 'Flight_Date+=+07-15', 'Destination+=+成都', 'Ticket_Fee+=+1290.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1340.', 'Origin_Code+=+KGT', 'Destination_Code+=+CTU'], ['Name+=+LU0/SHAE', 'Flight_Number+=+7080', 'Flight_Date+=+201905-2', 'Origin_Code+=+LF0'], ['Name+=+任玉柱', 'Flight_Number+=+FU6692', 'Flight_Date+=+11-11', 'Origin+=+晋江', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+360.0', 'Develop_Fee+=+50.0', 'Other_Fee+=+0.0', 'Origin_Code+=+JN', 'Destination_Code+=+XEY'], ['Name+=+YU/JE', 'Flight_Number+=+G5265', 'Flight_Date+=+04-17', 'Origin+=+HCJ', 'Destination+=+桂林', 'Ticket_Fee+=+240.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+240.', 'Destination_Code+=+KWL'], ['Name+=+姜肖施', 'Flight_Number+=+CA1975', 'Flight_Date+=+2019.08', 'Origin+=+上海浦东', 'Destination+=+长春', 'Ticket_Fee+=+1350.00', 'Total_Fee+=+1400.00', 'Origin_Code+=+PVG', 'Origin_Code+=+CGQ'], ['Name+=+李静', 'Flight_Number+=+CZ6954', 'Flight_Date+=+09-14', 'Origin+=+石家庄', 'Destination+=+大连', 'Ticket_Fee+=+880.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+940.0', 'Origin_Code+=+SJW', 'Destination_Code+=+DLC'], ['Name+=+朱美', 'Name+=+伍金技', 'Name+=+魏兰', 'Origin+=+HPGHPGO', 'Destination+=+武汉', 'Ticket_Fee+=+320.00', 'Total_Fee+=+370.00', 'Destination_Code+=+5H'], ['Name+=+陈洪传', 'Flight_Date+=+01-06', 'Origin+=+WMTWM', 'Destination+=+福州', 'Ticket_Fee+=+570.0', 'Other_Fee+=+0.0', 'Total_Fee+=+620.', 'Destination_Code+=+FOC'], ['Name+=+FANG/HUAN', 'Flight_Number+=+3790', 'Flight_Date+=+05-13', 'Flight_Date+=+05-14', 'Origin+=+锡林浩特', 'Destination+=+南苑', 'Destination+=+北京', 'Ticket_Fee+=+40.0', 'Develop_Fee+=+曼谷', 'Develop_Fee+=+8.0', 'Origin_Code+=+XIL', 'Origin_Code+=+PEK', 'Destination_Code+=+NAY', 'Destination_Code+=+BKK'], ['Name+=+ZHANG/BIHUA', 'Flight_Number+=+8L9858', 'Flight_Number+=+8L801', 'Flight_Number+=+8L9858', 'Flight_Number+=+8L801', 'Flight_Date+=+07-14', 'Flight_Date+=+07-15', 'Origin+=+腾冲', 'Destination+=+昆明', 'Destination+=+曼谷', 'Develop_Fee+=+8.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+MIN/XUENON', 'Flight_Number+=+GJ8889', 'Flight_Number+=+GJ8800', 'Flight_Number+=+GJ8889', 'Flight_Number+=+GJ8800', 'Flight_Date+=+08-15', 'Flight_Date+=+08-21', 'Destination+=+咸阳', 'Destination+=+CXR', 'Develop_Fee+=+90.0', 'Oil_Fee+=+400.0', 'Other_Fee+=+110.0', 'Origin_Code+=+XTY', 'Destination_Code+=+CXRG', 'Destination_Code+=+XIY'], ['Name+=+ZHOU/XUAN', 'Flight_Date+=+05-17', 'Flight_Date+=+05-18', 'Destination+=+上海红桥', 'Destination+=+上海浦东', 'Destination+=+樊谷', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+WMT', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+于嘉', 'Flight_Number+=+GS7895', 'Flight_Date+=+04-08', 'Origin+=+天津', 'Destination+=+广州', 'Ticket_Fee+=+2490.0', 'Total_Fee+=+2540.0', 'Origin_Code+=+TSN', 'Destination_Code+=+CAN'], ['Name+=+刘焕', 'Flight_Number+=+MU5535', 'Flight_Date+=+07-15', 'Origin+=+武夷山', 'Destination+=+南宁', 'Ticket_Fee+=+CNY1220.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+WUS', 'Destination_Code+=+NNG'], ['Name+=+何燕华', 'Name+=+大鉴', 'Flight_Number+=+GH3436', 'Flight_Date+=+2019-11', 'Origin+=+贵阳', 'Destination+=+深圳', 'Ticket_Fee+=+1120.00', 'Total_Fee+=+1170.0', 'Destination_Code+=+SZX'], ['Name+=+徐永坡', 'Flight_Number+=+CZ6906', 'Flight_Date+=+2019-01-23', 'Origin+=+北京', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+740.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Oil_Fee+=+700.0', 'Total_Fee+=+1440.0', 'Origin_Code+=+PEK', 'Destination_Code+=+URC'], ['Name+=+黄彬强', 'Flight_Number+=+3U8378', 'Flight_Date+=+11-19', 'Origin+=+大连', 'Destination+=+徐州', 'Ticket_Fee+=+CNY1210.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+CNYYQ50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY1310.0', 'Origin_Code+=+DLC', 'Destination_Code+=+XUZ'], ['Name+=+10/CHA0', 'Flight_Number+=+ZH9920', 'Flight_Date+=+04-26', 'Origin+=+台州', 'Destination+=+深圳', 'Ticket_Fee+=+1140.00', 'Develop_Fee+=+50.00', 'Total_Fee+=+1190.00', 'Origin_Code+=+HYN', 'Destination_Code+=+SZX'], ['Name+=+庞杨', 'Flight_Date+=+08-03', 'Origin+=+天津', 'Destination+=+大连', 'Ticket_Fee+=+1960.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY2010.0', 'Origin_Code+=+TSN', 'Destination_Code+=+DLC'], ['Name+=+ZHANG/LI', 'Flight_Number+=+ZH9916', 'Flight_Number+=+ZH9001', 'Flight_Number+=+ZH9916', 'Flight_Number+=+ZH9001', 'Flight_Date+=+04-29', 'Flight_Date+=+04-30', 'Origin+=+青岛', 'Destination+=+深圳', 'Destination+=+曼谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+31.0', 'Origin_Code+=+TAO', 'Destination_Code+=+SZX', 'Destination_Code+=+BKK'], ['Name+=+YANG/XIANMING', 'Flight_Number+=+CZ3306', 'Flight_Date+=+01-21', 'Origin+=+宁波', 'Destination+=+南', 'Ticket_Fee+=+1660.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.0', 'Total_Fee+=+710.0', 'Origin_Code+=+NGB', 'Destination_Code+=+NNG'], ['Name+=+杜秋娥', 'Flight_Number+=+EU2231', 'Flight_Date+=+05-22', 'Origin+=+右洲', 'Origin+=+WMT', 'Destination+=+福州', 'Ticket_Fee+=+1300.0', 'Develop_Fee+=+CNYCN', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0', 'Destination_Code+=+FOC'], ['Name+=+HU/F合NGF', 'Name+=+武五', 'Flight_Number+=+6H0076', 'Flight_Date+=+201'], ['Name+=+CHEN/YANLI', 'Flight_Date+=+07-11', 'Origin+=+桂林', 'Destination+=+舌港', 'Develop_Fee+=+90.0', 'Oil_Fee+=+106.0', 'Other_Fee+=+0.0', 'Origin_Code+=+KWL', 'Destination_Code+=+HKG'], ['Flight_Number+=+9L42', 'Flight_Number+=+FM853S', 'Flight_Number+=+9L42', 'Flight_Number+=+FM853S', 'Flight_Date+=+21JUL', 'Destination+=+上海浦东', 'Destination+=+又鲁', 'Ticket_Fee+=+1430', 'Develop_Fee+=+140', 'Destination_Code+=+BKK'], ['Name+=+ZHOU/YUANXN', 'Flight_Number+=+CZ8303', 'Flight_Date+=+07-16', 'Flight_Date+=+07-17', 'Origin+=+郑州', 'Destination+=+三亚', 'Destination+=+曼谷', 'Ticket_Fee+=+1760.0', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+32.0', 'Origin_Code+=+CGC', 'Destination_Code+=+SYX', 'Destination_Code+=+BKK'], ['Name+=+苏静', 'Flight_Number+=+C', 'Origin+=+上海浦东', 'Origin+=+成都', 'Destination+=+上海浦东', 'Origin_Code+=+PVG', 'Origin_Code+=+CTU', 'Destination_Code+=+PVG'], ['Name+=+从庆', 'Flight_Number+=+3479', 'Origin+=+重庆', 'Origin+=+上海', 'Destination+=+南宁', 'Ticket_Fee+=+330.0', 'Oil_Fee+=+1O.0', 'Total_Fee+=+6Y390.0', 'Origin_Code+=+CKG'], ['Name+=+李哲', 'Flight_Number+=+6416', 'Flight_Date+=+2019-10-20', 'Origin+=+昆明', 'Destination+=+沈阳', 'Ticket_Fee+=+1120.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1170.0', 'Origin_Code+=+MG', 'Destination_Code+=+SHE'], ['Name+=+邓晓华', 'Flight_Number+=+CZ3487', 'Flight_Date+=+2019-04-19', 'Origin+=+广州', 'Destination+=+昆明', 'Ticket_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+CAN', 'Destination_Code+=+KMG'], ['Name+=+ZOU/PAN', 'Flight_Number+=+5580', 'Flight_Number+=+MU541', 'Flight_Number+=+5580', 'Flight_Number+=+MU541', 'Flight_Date+=+福州', 'Flight_Date+=+07-14', 'Flight_Date+=+上海浦东', 'Flight_Date+=+07-15', 'Origin+=+上海虹桥', 'Origin+=+曼谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+FOC', 'Origin_Code+=+PVG', 'Destination_Code+=+SHA', 'Destination_Code+=+BKK'], ['Name+=+XU/ZHE', 'Flight_Date+=+03-15', 'Destination+=+重庆', 'Ticket_Fee+=+560.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+610.0', 'Origin_Code+=+HPG', 'Destination_Code+=+CKG'], ['Name+=+钱琳', 'Flight_Number+=+5454', 'Flight_Date+=+04-22', 'Origin+=+昆明', 'Destination+=+宁波', 'Ticket_Fee+=+870.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+920.0', 'Origin_Code+=+KMC', 'Destination_Code+=+NGB'], ['Name+=+李智', 'Flight_Number+=+CZ6505', 'Flight_Number+=+C26502', 'Flight_Number+=+CZ6505', 'Flight_Number+=+C26502', 'Flight_Date+=+2019-11-13', 'Flight_Date+=+2019-11-15', 'Origin+=+沈阳', 'Destination+=+上海浦东', 'Destination+=+沈阳', 'Ticket_Fee+=+2100.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2200.0', 'Origin_Code+=+SHE', 'Destination_Code+=+PVG', 'Destination_Code+=+SHE'], ['Name+=+陈军委', 'Flight_Number+=+6434', 'Origin+=+08-02', 'Destination+=+杭州', 'Destination+=+沈阳', 'Ticket_Fee+=+1160.0', 'Total_Fee+=+1220.0', 'Origin_Code+=+HGH', 'Destination_Code+=+SHE'], ['Name+=+ZHAO/YONGMR', 'Flight_Number+=+5156', 'Flight_Date+=+07-11', 'Origin+=+北京', 'Destination+=+上海虹桥', 'Destination+=+上东', 'Destination+=+导谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+PEK', 'Origin_Code+=+PVG', 'Destination_Code+=+SHA', 'Destination_Code+=+BKK'], ['Name+=+董翔旭', 'Flight_Number+=+CZ3654', 'Origin+=+北京', 'Destination+=+贵阳', 'Ticket_Fee+=+72030.0', 'Ticket_Fee+=+1980.0', 'Develop_Fee+=+50-0', 'Oil_Fee+=+0.0', 'Origin_Code+=+EK', 'Destination_Code+=+KWE'], ['Name+=+李晶', 'Flight_Number+=+7429', 'Flight_Date+=+05-28', 'Origin+=+杭州', 'Destination+=+长春', 'Ticket_Fee+=+580.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0', 'Other_Fee+=+0.0', 'Total_Fee+=+630.0', 'Origin_Code+=+HGH', 'Destination_Code+=+CGO'], ['Name+=+任玉柱', 'Name+=+林伍通', 'Flight_Number+=+CZ6320', 'Flight_Date+=+2019-06-21', 'Origin+=+西安', 'Destination+=+三亚', 'Ticket_Fee+=+800.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+850.0', 'Origin_Code+=+XIY', 'Destination_Code+=+SYX'], ['Name+=+龚雪', 'Origin+=+腾冲', 'Destination+=+昆明', 'Ticket_Fee+=+12600', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1310.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG'], ['Name+=+黎武平', 'Flight_Number+=+8L9844', 'Flight_Date+=+01-11', 'Origin+=+南昌', 'Destination+=+赣州', 'Ticket_Fee+=+CNY940.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+EXEMPTYQ0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY990.0', 'Origin_Code+=+KHN', 'Destination_Code+=+KOW'], ['Flight_Number+=+C7833', 'Flight_Date+=+2019-05-16', 'Origin+=+文', 'Destination+=+武汉', 'Destination+=+昌谷', 'Ticket_Fee+=+832.', 'Oil_Fee+=+8.00', 'Destination_Code+=+HPG', 'Destination_Code+=+EKK'], ['Name+=+LU/YANG', 'Flight_Number+=+3U8112', 'Flight_Date+=+04-07', 'Destination+=+成都', 'Ticket_Fee+=+6900', 'Develop_Fee+=+500', 'Oil_Fee+=+0.0', 'Total_Fee+=+740.0', 'Origin_Code+=+CDC', 'Destination_Code+=+CTU'], ['Name+=+ZHANG/YUNJIN', 'Destination+=+武汉', 'Ticket_Fee+=+290.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+340.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+GINL/RLIDXIA', 'Flight_Number+=+GY7183', 'Flight_Date+=+00.20', 'Origin+=+八', 'Destination+=+成都', 'Ticket_Fee+=+640.00', 'Total_Fee+=+690.00', 'Origin_Code+=+LPF', 'Destination_Code+=+CTU'], ['Name+=+曾亦强', 'Flight_Number+=+FM9182', 'Flight_Date+=+06-05', 'Origin+=+张家界', 'Destination+=+揭阳潮汕', 'Ticket_Fee+=+480.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+530.0', 'Origin_Code+=+DYG', 'Destination_Code+=+SWA'], ['Name+=+钱琳', 'Flight_Number+=+MU2770', 'Flight_Date+=+04-13', 'Origin+=+咸阳', 'Destination+=+南京', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY820.', 'Origin_Code+=+XIY', 'Destination_Code+=+NKG'], ['Name+=+YANG/FENGMR', 'Flight_Number+=+2485', 'Flight_Date+=+06-28', 'Origin+=+武汉', 'Destination+=+昆明', 'Destination+=+曼谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+WUH', 'Destination_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+YE/TIANYOU', 'Flight_Number+=+CZ', 'Destination+=+武汉', 'Ticket_Fee+=+290.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+340.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+FU/WEIL', 'Flight_Number+=+CA413', 'Flight_Date+=+01-04', 'Origin+=+成都', 'Destination+=+普吉', 'Develop_Fee+=+CNYCN9O.O', 'Oil_Fee+=+CNYYO330.0', 'Other_Fee+=+CNYXT12.0', 'Origin_Code+=+CTU', 'Destination_Code+=+HKT'], ['Name+=+ZOU/HAO', 'Flight_Number+=+5206', 'Flight_Date+=+07-18', 'Origin+=+舟山', 'Destination+=+上海浦东', 'Destination+=+曼谷', 'Ticket_Fee+=+1690.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Total_Fee+=+2320.0', 'Origin_Code+=+HSN', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+陆班', 'Flight_Number+=+CA', 'Flight_Number+=+8363', 'Flight_Number+=+CA', 'Flight_Number+=+8363', 'Flight_Date+=+201812-26', 'Destination+=+昆明', 'Develop_Fee+=+50.00', 'Oil_Fee+=+0.00', 'Total_Fee+=+X910.00'], ['Name+=+王陈', 'Flight_Date+=+10-16', 'Origin+=+重庆', 'Destination+=+天津', 'Ticket_Fee+=+C', 'Ticket_Fee+=+577.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+657.0', 'Origin_Code+=+CKG', 'Destination_Code+=+TSN'], ['Name+=+王伊诺', 'Flight_Number+=+CG0069', 'Flight_Date+=+2019-02-14', 'Origin+=+郑州', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+280.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Oil_Fee+=+0', 'Total_Fee+=+280.0', 'Destination_Code+=+URC'], ['Name+=+PENG/DAJU', 'Flight_Number+=+MU28', 'Flight_Number+=+MU2860', 'Flight_Number+=+MU2860', 'Flight_Date+=+08-24', 'Flight_Date+=+08-28', 'Origin+=+南京', 'Destination+=+南京', 'Ticket_Fee+=+200.0', 'Ticket_Fee+=+626.0', 'Other_Fee+=+260.0', 'Total_Fee+=+3106.0', 'Origin_Code+=+NKG', 'Destination_Code+=+KANSA', 'Destination_Code+=+IKX', 'Destination_Code+=+NKG'], ['Name+=+化自成', 'Flight_Number+=+6', 'Flight_Date+=+2019-1-58', 'Origin+=+上海浦东', 'Origin+=+大连', 'Ticket_Fee+=+670.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+00', 'Total_Fee+=+720', 'Origin_Code+=+DLC'], ['Name+=+ZHANGYUNJIN', 'Destination+=+西投', 'Origin_Code+=+HPG'], ['Name+=+MO/YANAN', 'Flight_Number+=+MU73', 'Flight_Number+=+MU74', 'Flight_Number+=+MU7402', 'Flight_Number+=+MU73', 'Flight_Number+=+MU7402', 'Flight_Date+=+07-23', 'Flight_Date+=+08-10', 'Origin+=+上海浦东', 'Destination+=+墨尔本', 'Destination+=+上海浦东', 'Develop_Fee+=+0.0', 'Oil_Fee+=+286.0', 'Other_Fee+=+1675.0', 'Origin_Code+=+PVG', 'Destination_Code+=+MEL', 'Destination_Code+=+PVG'], ['Name+=+王楷然', 'Flight_Number+=+26696', 'Flight_Date+=+201903-18', 'Origin+=+富蕴', 'Destination+=+马鲁木齐', 'Ticket_Fee+=+270.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+320.0', 'Origin_Code+=+FYN', 'Destination_Code+=+URC'], ['Name+=+LIU/YUAN', 'Flight_Number+=+G52694', 'Flight_Date+=+2019-04-23', 'Destination+=+贵阳', 'Ticket_Fee+=+60.00', 'Origin_Code+=+HC', 'Origin_Code+=+HCJ'], ['Name+=+于嘉', 'Flight_Number+=+G57896', 'Flight_Date+=+04-08', 'Origin+=+广州', 'Destination+=+天津', 'Ticket_Fee+=+1630.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1680.0', 'Origin_Code+=+CAN', 'Destination_Code+=+TSN'], ['Name+=+PFNG/SANMEI', 'Flight_Number+=+MU281', 'Flight_Date+=+26NOV', 'Ticket_Fee+=+2100', 'Other_Fee+=+428.00', 'Total_Fee+=+2618.00', 'Destination_Code+=+SGN'], ['Name+=+余涛', 'Flight_Number+=+CZ6954', 'Flight_Date+=+2018-11-25', 'Origin+=+石家庄', 'Destination+=+大连', 'Ticket_Fee+=+20.0', 'Total_Fee+=+520.0', 'Total_Fee+=+450', 'Destination_Code+=+DLC'], ['Name+=+李影南', 'Flight_Number+=+GJ8759', 'Flight_Date+=+09-02', 'Origin+=+杭州', 'Destination+=+兰州', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HGH', 'Destination_Code+=+LHW'], ['Name+=+陈会', 'Flight_Number+=+0Z364', 'Flight_Date+=+2019-04-12', 'Origin+=+柒江', 'Origin+=+西安', 'Ticket_Fee+=+680.0', 'Develop_Fee+=+50', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY730.0', 'Origin_Code+=+ZA'], ['Name+=+吴年娇', 'Flight_Number+=+CA1816', 'Flight_Date+=+10-18', 'Origin+=+厦门', 'Destination+=+北京', 'Ticket_Fee+=+2120.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2170.', 'Origin_Code+=+XMN', 'Destination_Code+=+PEK'], ['Name+=+国伍', 'Name+=+L有章', 'Flight_Number+=+CZ6093', 'Flight_Date+=+18MAY', 'Origin+=+北京', 'Destination+=+普吉', 'Ticket_Fee+=+1738.00', 'Origin_Code+=+ZHANG', 'Origin_Code+=+FENMS'], ['Name+=+蔡品伦', 'Flight_Number+=+EU2278', 'Flight_Date+=+03-19', 'Origin+=+温州', 'Destination+=+武汉', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY820.0', 'Origin_Code+=+WNZ', 'Destination_Code+=+WUH'], ['Name+=+张玉林', 'Flight_Number+=+ZH9334', 'Flight_Date+=+12-23', 'Origin+=+福州', 'Destination+=+郑州', 'Ticket_Fee+=+1250.0', 'Total_Fee+=+CNY1300.', 'Origin_Code+=+FOC'], ['Name+=+余益添', 'Flight_Number+=+MF1018', 'Flight_Date+=+08-28', 'Origin+=+广州', 'Destination+=+杭州', 'Ticket_Fee+=+1410.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1460.0', 'Origin_Code+=+CAN', 'Destination_Code+=+HGH'], ['Name+=+黄智艺', 'Flight_Date+=+01-06', 'Origin+=+WMTWM', 'Destination+=+福州', 'Ticket_Fee+=+570.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY620.', 'Destination_Code+=+FOC'], ['Name+=+LAI/SHUTINGMS', 'Flight_Number+=+MU2071', 'Flight_Date+=+07-03', 'Origin+=+北京', 'Destination+=+上海靖', 'Ticket_Fee+=+1320.0', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Total_Fee+=+1950.0', 'Origin_Code+=+PEK', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+CHEN/PENG', 'Flight_Number+=+MU2966', 'Flight_Date+=+06-19', 'Origin+=+珠海', 'Destination+=+长沙', 'Ticket_Fee+=+370.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY420.0', 'Origin_Code+=+ZUH', 'Destination_Code+=+CSX'], ['Name+=+YU/J1NJ11MS', 'Flight_Number+=+D2892', 'Flight_Date+=+2019-04', 'Origin+=+厂州', 'Destination+=+清通', 'Destination_Code+=+CX0'], ['Name+=+朱永秀', 'Flight_Number+=+CZ3828', 'Flight_Date+=+2019-08-25', 'Origin+=+南京', 'Destination+=+深圳', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+C', 'Total_Fee+=+50.0', 'Origin_Code+=+NKG', 'Destination_Code+=+SZX'], ['Name+=+钱琳', 'Flight_Number+=+7414', 'Flight_Number+=+HU7414', 'Flight_Number+=+7414', 'Flight_Number+=+HU7414', 'Flight_Date+=+05-16', 'Origin+=+宁波', 'Destination+=+太原', 'Ticket_Fee+=+CNY800.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY850.0', 'Origin_Code+=+NGB', 'Destination_Code+=+TYN'], ['Flight_Date+=+2018-09-17', 'Origin+=+ZHANG', 'Origin+=+武汉', 'Destination_Code+=+MFM'], ['Name+=+钱琳', 'Flight_Number+=+9', 'Flight_Number+=+MU9614', 'Flight_Number+=+9', 'Flight_Number+=+MU9614', 'Flight_Date+=+04-13', 'Origin+=+烟台', 'Destination+=+咸阳', 'Ticket_Fee+=+720.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY', 'Total_Fee+=+770', 'Origin_Code+=+YNT', 'Destination_Code+=+XIY'], ['Name+=+YAN/HONGOIONGMS', 'Flight_Number+=+8L9710', 'Flight_Number+=+8L809', 'Flight_Number+=+8L9710', 'Flight_Number+=+8L809', 'Flight_Date+=+05-19', 'Flight_Date+=+05-20', 'Destination+=+昆明', 'Destination+=+清迈', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+332.0', 'Origin_Code+=+LCX', 'Destination_Code+=+KMG', 'Destination_Code+=+CNX'], ['Name+=+张志兵', 'Flight_Number+=+MU5708', 'Flight_Date+=+08-11', 'Origin+=+北京', 'Destination+=+昆明', 'Ticket_Fee+=+C', 'Develop_Fee+=+50', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1710.', 'Origin_Code+=+PEK', 'Destination_Code+=+KMG'], ['Name+=+CHEN/XIANGBO', 'Flight_Number+=+3718', 'Flight_Date+=+06-07', 'Flight_Date+=+06-08', 'Origin+=+呼和浩特', 'Destination+=+宁波', 'Destination+=+曼谷', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Total_Fee+=+482.0', 'Origin_Code+=+HET', 'Destination_Code+=+NGB', 'Destination_Code+=+BKK'], ['Name+=+9FEI/RUILAN', 'Flight_Number+=+CA831', 'Flight_Date+=+09-14', 'Origin+=+北京', 'Destination+=+冲绳', 'Ticket_Fee+=+310.0', 'Develop_Fee+=+90.0', 'Other_Fee+=+0.0', 'Origin_Code+=+PEK国', 'Destination_Code+=+OKA'], ['Name+=+WANG/YI', 'Flight_Number+=+5546', 'Flight_Date+=+07-07', 'Flight_Date+=+07-08', 'Origin+=+烟台', 'Destination+=+上海浦东', 'Destination+=+曼谷', 'Develop_Fee+=+0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+YNT', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+杨振', 'Flight_Date+=+05-18', 'Origin+=+北京', 'Destination+=+杭州', 'Ticket_Fee+=+CNY2200.0', 'Develop_Fee+=+CNY', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+2250.0', 'Origin_Code+=+PEK', 'Destination_Code+=+HG'], ['Name+=+委彦波', 'Flight_Number+=+GS7657', 'Flight_Date+=+01-06', 'Origin+=+咸阳', 'Destination+=+南京', 'Ticket_Fee+=+500.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+Q.0', 'Other_Fee+=+0.0', 'Total_Fee+=+550.0', 'Origin_Code+=+XY', 'Destination_Code+=+NKG'], ['Flight_Number+=+HX161', 'Flight_Date+=+08-30', 'Flight_Date+=+09-01', 'Origin+=+香港', 'Destination+=+三亚', 'Destination+=+香港', 'Ticket_Fee+=+16', 'Oil_Fee+=+81.0', 'Total_Fee+=+108', 'Origin_Code+=+HKG', 'Destination_Code+=+SYX', 'Destination_Code+=+HKG'], ['Name+=+HU/JIALI', 'Flight_Number+=+MU73', 'Flight_Number+=+MU74', 'Flight_Number+=+MU7402', 'Flight_Number+=+MU73', 'Flight_Number+=+MU7402', 'Flight_Date+=+07-23', 'Flight_Date+=+08-10', 'Origin+=+上海浦东', 'Destination+=+尔本', 'Destination+=+上海浦东', 'Develop_Fee+=+90.0', 'Oil_Fee+=+286.0', 'Total_Fee+=+1675.0', 'Origin_Code+=+PVG', 'Destination_Code+=+MEL', 'Destination_Code+=+PVG'], ['Name+=+蔡品伦', 'Flight_Number+=+9830', 'Flight_Date+=+01-12', 'Origin+=+长春', 'Destination+=+烟台', 'Ticket_Fee+=+320.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+CGQ', 'Destination_Code+=+YNT'], ['Name+=+詹萌', 'Flight_Number+=+CZ6581', 'Flight_Number+=+CZ6452', 'Flight_Number+=+CZ6581', 'Flight_Number+=+CZ6452', 'Flight_Date+=+2019-10-11', 'Flight_Date+=+2019-10-13', 'Origin+=+沈阳', 'Destination+=+南京', 'Destination+=+沈阳', 'Ticket_Fee+=+1240.0', 'Develop_Fee+=+100.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1340.0', 'Origin_Code+=+SHE', 'Destination_Code+=+NKG', 'Destination_Code+=+SHE'], ['Name+=+ZHANG/MINGHE', 'Flight_Number+=+8L9984', 'Flight_Number+=+8L801', 'Flight_Number+=+8L9984', 'Flight_Number+=+8L801', 'Flight_Date+=+07-02', 'Flight_Date+=+07-03', 'Origin+=+咸阳', 'Destination+=+昆明', 'Destination+=+曼谷', 'Oil_Fee+=+8.0', 'Other_Fee+=+232.0', 'Origin_Code+=+XIY', 'Destination_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+潘志金', 'Origin+=+广州', 'Destination+=+昆明', 'Ticket_Fee+=+1050.0', 'Develop_Fee+=+0.0', 'Total_Fee+=+67100.0', 'Destination_Code+=+KMG'], ['Name+=+解庆锋', 'Flight_Number+=+C7818', 'Flight_Date+=+2018-10-29', 'Origin+=+杭州', 'Destination+=+重庆', 'Ticket_Fee+=+900.0', 'Develop_Fee+=+50.O', 'Oil_Fee+=+10.0', 'Total_Fee+=+960.0', 'Origin_Code+=+HGH', 'Destination_Code+=+CKG'], ['Name+=+谈亚强', 'Flight_Date+=+08-09', 'Origin+=+上海浦东', 'Destination+=+重庆', 'Ticket_Fee+=+960.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY1020', 'Origin_Code+=+PVG', 'Destination_Code+=+CKG'], ['Name+=+张瑞娟', 'Flight_Number+=+GS', 'Flight_Date+=+10-16', 'Origin+=+重庆', 'Destination+=+天津', 'Ticket_Fee+=+577.0', 'Oil_Fee+=+30.', 'Total_Fee+=+CNY657.0', 'Origin_Code+=+CKG', 'Destination_Code+=+TSN'], ['Name+=+李风兰', 'Origin+=+徐州', 'Destination+=+哈尔滨', 'Ticket_Fee+=+2090.0', 'Develop_Fee+=+5O.O', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+2140.0', 'Origin_Code+=+XUZ', 'Destination_Code+=+HRB'], ['Name+=+赵玉双', 'Name+=+木杰', 'Flight_Number+=+CZ6714', 'Flight_Date+=+07-05', 'Ticket_Fee+=+CNY1650.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+PEK', 'Destination_Code+=+SYX'], ['Name+=+张舒冬', 'Flight_Number+=+CZ6709', 'Flight_Date+=+2019-04-1712-35', 'Origin+=+厦门', 'Destination+=+大连', 'Ticket_Fee+=+1590.00', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1640.0', 'Origin_Code+=+XMN', 'Destination_Code+=+DLC'], ['Name+=+YU/LIANG', 'Flight_Number+=+G52654', 'Flight_Date+=+03-21', 'Origin+=+HC', 'Destination+=+桂林', 'Ticket_Fee+=+180.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+230.0', 'Origin_Code+=+HCJ', 'Destination_Code+=+KWL'], ['Name+=+冯杰', 'Flight_Number+=+EU281', 'Flight_Date+=+05-02', 'Destination+=+哈尔滨', 'Ticket_Fee+=+CNY500.0', 'Total_Fee+=+CNY500.0', 'Origin_Code+=+DTU', 'Destination_Code+=+HRB'], ['Name+=+谢明有', 'Destination+=+成都', 'Ticket_Fee+=+1480.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1530.0', 'Origin_Code+=+LZY', 'Destination_Code+=+CTU'], ['Name+=+TANG/KEMR', 'Flight_Date+=+05-18', 'Origin+=+武汉', 'Destination+=+广州', 'Destination+=+曼谷', 'Ticket_Fee+=+CNY1670.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+32.0', 'Total_Fee+=+CNY', 'Total_Fee+=+1850.0', 'Origin_Code+=+WUH', 'Destination_Code+=+CAN', 'Destination_Code+=+BKK'], ['Name+=+强刚', 'Flight_Number+=+9148', 'Flight_Number+=+FM9148', 'Flight_Number+=+9148', 'Flight_Number+=+FM9148', 'Flight_Date+=+03-11', 'Origin+=+天津', 'Destination+=+上海虹桥', 'Ticket_Fee+=+2110.0', 'Develop_Fee+=+0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2160.', 'Origin_Code+=+TSN', 'Destination_Code+=+SHA'], ['Name+=+工有', 'Flight_Date+=+23AUG', 'Destination+=+C', 'Total_Fee+=+4878.00', 'Destination_Code+=+CJU'], ['Name+=+齐湖', 'Flight_Number+=+DJ0517', 'Origin+=+三亚', 'Destination+=+西安', 'Ticket_Fee+=+800.00', 'Develop_Fee+=+50:00', 'Oil_Fee+=+0:00', 'Total_Fee+=+850.00', 'Origin_Code+=+XIY'], ['Name+=+ZHANG/LU', 'Flight_Number+=+G5265', 'Flight_Date+=+05-10', 'Destination+=+桂林', 'Ticket_Fee+=+120.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+120.', 'Origin_Code+=+HCJ', 'Destination_Code+=+KWL'], ['Name+=+CHENG/FAKE', 'Flight_Number+=+2262', 'Flight_Date+=+06-22', 'Origin+=+湛江', 'Destination+=+重庆', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+900.0', 'Origin_Code+=+ZHA', 'Destination_Code+=+CKG'], ['Name+=+刘发贵', 'Flight_Number+=+6950', 'Flight_Date+=+03-12', 'Origin+=+昆明', 'Destination+=+重庆', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.0', 'Total_Fee+=+50.0', 'Origin_Code+=+KMC', 'Destination_Code+=+CKG'], ['Name+=+陈素珍', 'Flight_Date+=+07.07', 'Destination+=+桂林', 'Ticket_Fee+=+180.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+180.0', 'Origin_Code+=+HCJ', 'Destination_Code+=+KWL'], ['Name+=+李姝', 'Origin+=+上海浦东', 'Origin+=+长春', 'Destination+=+上海浦', 'Ticket_Fee+=+1000.0', 'Develop_Fee+=+0.50', 'Total_Fee+=+6.10', 'Total_Fee+=+50.0', 'Origin_Code+=+PVG', 'Origin_Code+=+CGQ'], ['Name+=+王浩', 'Flight_Number+=+8L9870', 'Flight_Date+=+06-20', 'Origin+=+青岛', 'Destination+=+武汉', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+TAO', 'Destination_Code+=+WUH'], ['Name+=+任玉柱', 'Flight_Number+=+FU6691', 'Flight_Date+=+11-11', 'Origin+=+咸阳', 'Destination+=+晋江', 'Ticket_Fee+=+370.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+XYF', 'Destination_Code+=+JN'], ['Name+=+ZENG/CHAO', 'Flight_Number+=+G52654', 'Flight_Date+=+07-01', 'Destination+=+重庆', 'Ticket_Fee+=+CNY430.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+O.0', 'Total_Fee+=+430.0', 'Destination_Code+=+CKG', 'Destination_Code+=+XXX'], ['Name+=+陈希东', 'Flight_Number+=+CZ6128', 'Flight_Date+=+2019-08-09', 'Origin+=+北京', 'Destination+=+大连', 'Ticket_Fee+=+CNY1120.0', 'Develop_Fee+=+CNY50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1170.0', 'Origin_Code+=+PEK', 'Destination_Code+=+DLC'], ['Name+=+冯涛', 'Flight_Number+=+MU2314', 'Flight_Date+=+07-16', 'Origin+=+西宁', 'Destination+=+成阳', 'Ticket_Fee+=+CNY330.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY380.0', 'Origin_Code+=+XNN', 'Destination_Code+=+XIY'], ['Name+=+晏涨龙', 'Flight_Date+=+11-22', 'Origin+=+贵阳', 'Destination+=+六盘水', 'Ticket_Fee+=+CNY30.0', 'Develop_Fee+=+NYCN50.', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY280.', 'Origin_Code+=+KWE', 'Destination_Code+=+LPF'], ['Name+=+丁治祥', 'Flight_Number+=+CZ3595', 'Origin+=+广州', 'Destination+=+上海虹桥', 'Ticket_Fee+=+1820', 'Ticket_Fee+=+1980.00', 'Oil_Fee+=+O.6', 'Origin_Code+=+CAN', 'Destination_Code+=+SHA'], ['Name+=+化世南', 'Flight_Number+=+7988', 'Flight_Date+=+12-30', 'Destination+=+西安', 'Destination+=+天津', 'Ticket_Fee+=+0030.00', 'Develop_Fee+=+50.00', 'Oil_Fee+=+0.0', 'Destination_Code+=+XY6', 'Destination_Code+=+TSN'], ['Name+=+郭念', 'Flight_Number+=+90', 'Flight_Date+=+12-10', 'Origin+=+广州', 'Ticket_Fee+=+1390.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1440.', 'Origin_Code+=+CAN', 'Destination_Code+=+WUX'], ['Name+=+CHEN/LIANLI', 'Flight_Number+=+ZH8916', 'Flight_Date+=+05-17', 'Origin+=+三亚', 'Destination+=+惠州', 'Ticket_Fee+=+CNY480.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY530.0', 'Origin_Code+=+SYX', 'Destination_Code+=+HUZ'], ['Flight_Number+=+3U8600', 'Flight_Date+=+2019-05-23', 'Destination+=+西安成阳', 'Ticket_Fee+=+800.00', 'Develop_Fee+=+5Q.O', 'Oil_Fee+=+0', 'Total_Fee+=+0.00'], ['Name+=+张玉林', 'Flight_Number+=+JR1463', 'Flight_Date+=+11-23', 'Origin+=+武汉', 'Destination+=+揭阳潮油', 'Ticket_Fee+=+CN450.0', 'Develop_Fee+=+CN50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY500.0', 'Origin_Code+=+WUH', 'Destination_Code+=+SWA'], ['Name+=+林岳铨', 'Flight_Number+=+CZ369R', 'Flight_Date+=+2018-12', 'Origin+=+南京', 'Destination+=+广州', 'Ticket_Fee+=+CNY1440.0', 'Develop_Fee+=+CNY50.0', 'Oil_Fee+=+CNY50.0', 'Origin_Code+=+NKG', 'Destination_Code+=+CAN'], ['Flight_Date+=+2019-04-08', 'Destination+=+普吉', 'Ticket_Fee+=+476', 'Ticket_Fee+=+1000', 'Other_Fee+=+10', 'Total_Fee+=+1576', 'Destination_Code+=+HKT'], ['Name+=+赵建杰', 'Name+=+木得', 'Flight_Number+=+A01145', 'Flight_Date+=+2019-03-11', 'Origin+=+贵阳龙汇堡', 'Destination+=+宜昌', 'Destination+=+三峡', 'Ticket_Fee+=+30900', 'Develop_Fee+=+50.00', 'Oil_Fee+=+0,00', 'Total_Fee+=+0.00', 'Total_Fee+=+71.250.0', 'Origin_Code+=+KWE'], ['Name+=+程英华', 'Flight_Number+=+CZ8076', 'Flight_Date+=+2019-05-20', 'Origin+=+神农架', 'Destination+=+武汉', 'Ticket_Fee+=+0.0', 'Total_Fee+=+CNY0.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+黄彬强', 'Flight_Number+=+CA8938', 'Flight_Date+=+11-17', 'Destination+=+大连', 'Ticket_Fee+=+CNY1210.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+CNYYQ50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY1310.0', 'Origin_Code+=+WDS', 'Destination_Code+=+DLC'], ['Name+=+瞿槿芊(童票)', 'Flight_Number+=+98', 'Flight_Date+=+04-18', 'Origin+=+南京', 'Destination+=+广州', 'Ticket_Fee+=+720.0', 'Other_Fee+=+0.0', 'Total_Fee+=+720.', 'Origin_Code+=+NKG', 'Destination_Code+=+CAN'], ['Name+=+龚坚', 'Flight_Number+=+64', 'Flight_Date+=+05-16', 'Origin+=+南京', 'Destination+=+南宁', 'Ticket_Fee+=+1000.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1050.0', 'Origin_Code+=+NKG', 'Destination_Code+=+NN'], ['Name+=+晁汐(南通)', 'Flight_Number+=+3U822', 'Flight_Number+=+3U8220', 'Flight_Number+=+3U8220', 'Flight_Date+=+03-10', 'Destination+=+武汉', 'Ticket_Fee+=+680.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+730.0', 'Origin_Code+=+HPG', 'Origin_Code+=+HPC', 'Destination_Code+=+WUH'], ['Name+=+卢云恺', 'Flight_Number+=+CZ6599', 'Flight_Date+=+2019-0217', 'Origin+=+郑州', 'Destination+=+鄂尔多斯', 'Ticket_Fee+=+CNY0.0', 'Develop_Fee+=+CNY0.0', 'Oil_Fee+=+CNY0.0', 'Total_Fee+=+CNY0.0', 'Origin_Code+=+CG0', 'Destination_Code+=+DSN'], ['Name+=+陆效', 'Name+=+何成', 'Flight_Number+=+C76954', 'Flight_Date+=+1208', 'Origin+=+石家庄', 'Destination+=+董连', 'Ticket_Fee+=+880.00', 'Develop_Fee+=+5000', 'Oil_Fee+=+0.00', 'Total_Fee+=+940.0', 'Total_Fee+=+0.70', 'Origin_Code+=+SJW', 'Destination_Code+=+DLC'], ['Origin+=+中', 'Origin+=+HPGHPG', 'Destination+=+邵郑', 'Destination+=+武汉', 'Ticket_Fee+=+320.00', 'Total_Fee+=+370.00'], ['Name+=+日', 'Flight_Number+=+CZB076', 'Flight_Date+=+03+16', 'Origin+=+神农渠', 'Destination+=+重庆', 'Ticket_Fee+=+850.00', 'Develop_Fee+=+500', 'Oil_Fee+=+0', 'Total_Fee+=+900.00', 'Origin_Code+=+HPG', 'Destination_Code+=+CKG'], ['Name+=+陈忠达', 'Flight_Number+=+FM9526', 'Flight_Date+=+06-09', 'Origin+=+温州', 'Destination+=+上海浦东', 'Ticket_Fee+=+CN', 'Ticket_Fee+=+1430.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1480.0', 'Origin_Code+=+WNZ', 'Destination_Code+=+PVG'], ['Name+=+冯杰', 'Flight_Number+=+FM9244', 'Flight_Date+=+07-22', 'Origin+=+黄山', 'Destination+=+温州', 'Ticket_Fee+=+520.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+570.0', 'Origin_Code+=+TXN', 'Destination_Code+=+WNZ'], ['Name+=+杨颖', 'Flight_Number+=+ZH831', 'Flight_Date+=+01-14', 'Origin+=+襄樊', 'Destination+=+珠海', 'Ticket_Fee+=+CNY880.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY930.0', 'Origin_Code+=+XFN', 'Destination_Code+=+ZUH'], ['Name+=+谢志红', 'Flight_Number+=+CZ3373', 'Flight_Date+=+2019-08-13', 'Origin+=+广州', 'Destination+=+西宁', 'Ticket_Fee+=+1320.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1370.0', 'Origin_Code+=+CAN', 'Destination_Code+=+XN'], ['Name+=+刘小锋', 'Flight_Number+=+Y87506', 'Flight_Date+=+12-21', 'Origin+=+武汉', 'Destination+=+上海浦', 'Ticket_Fee+=+300.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+360.0', 'Origin_Code+=+WUH'], ['Name+=+HU/HONGXIA', 'Flight_Number+=+CZ6387', 'Flight_Date+=+01-02', 'Origin+=+图里TOT', 'Origin+=+上海浦东', 'Ticket_Fee+=+CNY350.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+30.0', 'Other_Fee+=+0.0', 'Total_Fee+=+430.0', 'Origin_Code+=+KWE', 'Destination_Code+=+PV'], ['Name+=+YANG/JIAN', 'Flight_Number+=+FM831', 'Flight_Date+=+05-23', 'Origin+=+珠海', 'Origin+=+上海虹桥', 'Destination+=+上海浦东', 'Destination+=+普', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+ZUH', 'Origin_Code+=+PVG', 'Destination_Code+=+SHA', 'Destination_Code+=+HKT'], ['Name+=+刘燕芳', 'Flight_Number+=+C23380', 'Flight_Date+=+20190622', 'Origin+=+广州', 'Destination+=+长沙', 'Ticket_Fee+=+1260.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Total_Fee+=+1310.0', 'Origin_Code+=+CAN', 'Destination_Code+=+CSX'], ['Name+=+吴年娇', 'Flight_Number+=+JR14', 'Flight_Date+=+11-23', 'Origin+=+武汉', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+345.0', 'Develop_Fee+=+5', 'Oil_Fee+=+0.0', 'Total_Fee+=+395.0', 'Origin_Code+=+WUH', 'Destination_Code+=+XY'], ['Name+=+刘爱霞', 'Flight_Number+=+2918', 'Flight_Date+=+08-01', 'Origin+=+广州', 'Ticket_Fee+=+1540.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1590.0', 'Origin_Code+=+CAN', 'Destination_Code+=+WWUX'], ['Name+=+纪丽', 'Flight_Number+=+5769', 'Flight_Number+=+MU5769', 'Flight_Number+=+5769', 'Flight_Number+=+MU5769', 'Flight_Date+=+07-01', 'Origin+=+腾冲', 'Destination+=+成都', 'Ticket_Fee+=+CNY1200.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+00', 'Other_Fee+=+0.0', 'Total_Fee+=+1250.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+CTU'], ['Name+=+WANG/JICHAO', 'Flight_Number+=+MU5634', 'Flight_Number+=+MU9857', 'Flight_Number+=+MU5634', 'Flight_Number+=+MU9857', 'Flight_Date+=+03-20', 'Flight_Date+=+03-21', 'Origin+=+乌鲁木齐', 'Destination+=+上海虹桥', 'Destination+=+上海浦东', 'Ticket_Fee+=+CNY4114.0', 'Develop_Fee+=+CNYCN0', 'Oil_Fee+=+CNY', 'Oil_Fee+=+8.0', 'Other_Fee+=+481.0', 'Total_Fee+=+4743.0', 'Origin_Code+=+URC', 'Destination_Code+=+SHA', 'Destination_Code+=+PVG'], ['Name+=+贺晓杰', 'Flight_Number+=+TV6011', 'Flight_Date+=+07-11', 'Origin+=+太原', 'Destination+=+烟台', 'Ticket_Fee+=+670.0', 'Develop_Fee+=+CNYCN5O.O', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+730.0', 'Origin_Code+=+TYN', 'Destination_Code+=+YNT'], ['Name+=+李琳卫', 'Name+=+余菊香', 'Flight_Number+=+MU5372', 'Flight_Date+=+05-18', 'Origin+=+武汉', 'Destination+=+上海浦东', 'Ticket_Fee+=+CNY870.0', 'Develop_Fee+=+C', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY920.0', 'Origin_Code+=+WUH', 'Destination_Code+=+PVG'], ['Name+=+何杰', 'Flight_Number+=+CZ6818', 'Flight_Date+=+2018-11-2511:50', 'Origin+=+和田', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+HTN', 'Destination_Code+=+URC'], ['Name+=+戴萍', 'Flight_Number+=+CZ6997', 'Flight_Date+=+2019-01-27', 'Origin+=+喀什', 'Destination+=+上海虹桥', 'Ticket_Fee+=+2950.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY', 'Total_Fee+=+3000.0', 'Origin_Code+=+KHG', 'Destination_Code+=+SHA'], ['Name+=+吴定韵', 'Flight_Number+=+9505', 'Flight_Date+=+09-17', 'Origin+=+长春', 'Destination+=+烟台', 'Ticket_Fee+=+630.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+690.0', 'Origin_Code+=+CGQ', 'Destination_Code+=+YNT'], ['Name+=+石祚宝', 'Flight_Number+=+2918', 'Flight_Date+=+08-01', 'Origin+=+广州', 'Ticket_Fee+=+1540.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1590.0', 'Origin_Code+=+CAN', 'Destination_Code+=+WUX'], ['Name+=+杨苏元', 'Flight_Number+=+MU5661', 'Flight_Date+=+08-22', 'Origin+=+上海浦东', 'Destination+=+大连', 'Ticket_Fee+=+730.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+790.0', 'Origin_Code+=+PVG', 'Destination_Code+=+DLC'], ['Name+=+陈巍', 'Flight_Number+=+SC4696', 'Flight_Date+=+12-02', 'Origin+=+南京', 'Destination+=+青岛', 'Ticket_Fee+=+1350.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1400.0', 'Origin_Code+=+NKG', 'Destination_Code+=+TAO'], ['Name+=+黄宗印', 'Origin+=+武汉', 'Ticket_Fee+=+450.0', 'Total_Fee+=+CNY500.', 'Origin_Code+=+WUE', 'Destination_Code+=+HPG'], ['Name+=+张展瑞', 'Flight_Number+=+HU7201', 'Flight_Date+=+08-03', 'Origin+=+天津', 'Destination+=+广州', 'Ticket_Fee+=+CNY', 'Ticket_Fee+=+2070.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+TSN', 'Destination_Code+=+CAN'], ['Name+=+CHEN', 'Flight_Number+=+CZ3630', 'Flight_Date+=+2019-04-09', 'Origin+=+GUANGZHOU', 'Destination+=+BANGKOK', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Origin_Code+=+CAN', 'Destination_Code+=+BKK'], ['Name+=+李先兵', 'Flight_Number+=+9H8309', 'Flight_Date+=+05-01', 'Origin+=+咸阳', 'Destination+=+大连', 'Ticket_Fee+=+CNY530.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY580.0', 'Origin_Code+=+XY', 'Destination_Code+=+DLC'], ['Name+=+WANG/PENG', 'Flight_Number+=+C78076', 'Flight_Date+=+201', 'Destination+=+武汉', 'Ticket_Fee+=+400', 'Origin_Code+=+HPG', 'Origin_Code+=+HP'], ['Name+=+沈广华', 'Flight_Number+=+CZ6662', 'Flight_Date+=+2019-0213', 'Origin+=+乌鲁木齐', 'Destination+=+义乌', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+50.0', 'Origin_Code+=+URC', 'Destination_Code+=+YIW'], ['Flight_Date+=+2019-04-27', 'Origin+=+西安', 'Destination+=+广州', 'Ticket_Fee+=+930.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+960.', 'Origin_Code+=+XIY', 'Destination_Code+=+CAN'], ['Name+=+杨凤', 'Flight_Number+=+CZ8076', 'Destination+=+武汉', 'Develop_Fee+=+0.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+L/LIQUAN', 'Flight_Date+=+03-14', 'Destination+=+武汉', 'Ticket_Fee+=+490.0', 'Develop_Fee+=+5', 'Oil_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+GHP', 'Destination_Code+=+WUH'], ['Name+=+冯杰', 'Flight_Date+=+07-15', 'Origin+=+深圳', 'Destination+=+天津', 'Ticket_Fee+=+2110.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2160.0', 'Origin_Code+=+SZX', 'Destination_Code+=+TSN'], ['Flight_Number+=+J05175', 'Flight_Date+=+U017', 'Origin+=+三亚', 'Destination+=+西安', 'Ticket_Fee+=+800.00', 'Develop_Fee+=+50:00', 'Oil_Fee+=+0', 'Total_Fee+=+850.00', 'Origin_Code+=+SYK', 'Destination_Code+=+XIY'], ['Name+=+芦士埠', 'Flight_Number+=+CZ3108', 'Flight_Date+=+05-18', 'Origin+=+北京首', 'Origin+=+北京', 'Destination+=+广州白云', 'Destination+=+广州', 'Ticket_Fee+=+2310.0', 'Origin_Code+=+PEK', 'Destination_Code+=+CAN'], ['Flight_Number+=+CZ3966', 'Origin+=+上海虹桥', 'Destination+=+深圳', 'Develop_Fee+=+CNY.50.0', 'Oil_Fee+=+270.0', 'Total_Fee+=+61280.0', 'Origin_Code+=+SHA', 'Origin_Code+=+SZX'], ['Name+=+张永朝', 'Flight_Number+=+GS6633', 'Flight_Date+=+09-02', 'Origin+=+呼和浩特', 'Destination+=+沈阳', 'Ticket_Fee+=+680.0', 'Develop_Fee+=+50', 'Origin_Code+=+HET', 'Destination_Code+=+SHE'], ['Name+=+李平', 'Flight_Date+=+08-28', 'Origin+=+郑州', 'Destination+=+三亚', 'Ticket_Fee+=+2050.0', 'Oil_Fee+=+0.0', 'Oil_Fee+=+30.0', 'Total_Fee+=+CNY2110.0', 'Origin_Code+=+CGO', 'Destination_Code+=+SYX'], ['Name+=+罗小晶', 'Flight_Number+=+CZ3104', 'Flight_Date+=+2019-0419', 'Origin+=+北京', 'Destination+=+广州', 'Ticket_Fee+=+1160.0', 'Total_Fee+=+1210.0', 'Origin_Code+=+PEK', 'Destination_Code+=+CAN'], ['Name+=+彭俊', 'Flight_Date+=+09-25', 'Origin+=+遵义', 'Destination+=+广州', 'Ticket_Fee+=+5验0', 'Develop_Fee+=+50.0', 'Other_Fee+=+0.O', 'Total_Fee+=+550.0', 'Origin_Code+=+ZY', 'Destination_Code+=+CAN'], ['Name+=+黄梓舒', 'Flight_Number+=+7624', 'Flight_Date+=+07-23', 'Destination+=+北京', 'Ticket_Fee+=+630.0', 'Oil_Fee+=+10.', 'Other_Fee+=+0.0', 'Total_Fee+=+690.0', 'Origin_Code+=+DOY', 'Destination_Code+=+PEK'], ['Name+=+张旭', 'Flight_Number+=+9H6007', 'Flight_Date+=+03-18', 'Origin+=+咸阳', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+800.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+850.0', 'Origin_Code+=+XIY', 'Destination_Code+=+URC'], ['Name+=+ZHANG/SHUHUA', 'Flight_Number+=+G52654', 'Flight_Date+=+05-31', 'Destination+=+重庆', 'Ticket_Fee+=+660.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+660.0', 'Origin_Code+=+HCJ', 'Destination_Code+=+CKG'], ['Name+=+TIAN/ZHUORONG', 'Flight_Date+=+05-06', 'Destination+=+重庆', 'Ticket_Fee+=+1200.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1200.', 'Origin_Code+=+LLB', 'Destination_Code+=+CKC'], ['Name+=+吴昊阳', 'Flight_Number+=+3U8432', 'Flight_Date+=+04-27', 'Origin+=+三亚', 'Destination+=+常州', 'Ticket_Fee+=+2060.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY2110.0', 'Origin_Code+=+SYX', 'Destination_Code+=+CZX'], ['Name+=+米红萍', 'Flight_Number+=+CZ3940', 'Flight_Date+=+11-25', 'Origin+=+郑州', 'Destination+=+杭州', 'Destination+=+通明', 'Ticket_Fee+=+660.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+760.0', 'Origin_Code+=+CGO', 'Destination_Code+=+HGH'], ['Name+=+易福军', 'Flight_Number+=+G52654', 'Flight_Date+=+07-10', 'Destination+=+桂林', 'Ticket_Fee+=+180.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Total_Fee+=+180.0', 'Origin_Code+=+HCHC', 'Destination_Code+=+KWL'], ['Name+=+陈方家', 'Flight_Number+=+CZ332', 'Flight_Date+=+02-20', 'Origin+=+长沙', 'Destination+=+广州', 'Ticket_Fee+=+1280', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+O.0', 'Total_Fee+=+330.0', 'Origin_Code+=+CSX', 'Destination_Code+=+CAN'], ['Name+=+曹盼', 'Flight_Number+=+KY', 'Origin+=+腾冲', 'Destination+=+昆明', 'Ticket_Fee+=+1260.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1310.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG'], ['Name+=+赵建杰', 'Flight_Number+=+1074', 'Flight_Number+=+HO1074', 'Flight_Number+=+1074', 'Flight_Number+=+HO1074', 'Flight_Date+=+03-08', 'Origin+=+武汉', 'Destination+=+上海浦东', 'Ticket_Fee+=+CNY530.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY580.0', 'Origin_Code+=+WUH', 'Destination_Code+=+PVG'], ['Name+=+LU/BAIYU', 'Flight_Number+=+G52694', 'Flight_Date+=+04-16', 'Origin+=+HCJ', 'Destination+=+贵阳', 'Ticket_Fee+=+C', 'Ticket_Fee+=+220.', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY220.0', 'Destination_Code+=+KWE'], ['Name+=+YANG/MING', 'Origin+=+桂林', 'Destination+=+昆明', 'Develop_Fee+=+5O.', 'Other_Fee+=+0.0', 'Total_Fee+=+粥', 'Total_Fee+=+90.0', 'Origin_Code+=+KWL', 'Destination_Code+=+KMG'], ['Name+=+黄朝枝', 'Flight_Date+=+04-10', 'Origin+=+沈阳', 'Ticket_Fee+=+CNY1010.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1060.0', 'Origin_Code+=+SHE', 'Destination_Code+=+RIZ'], ['Name+=+詹吉泉', 'Flight_Number+=+C23538', 'Flight_Date+=+2019-0-12', 'Origin+=+上海虹桥', 'Destination+=+广州', 'Destination+=+上海虹桥', 'Ticket_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+16Z.0', 'Total_Fee+=+162.0', 'Origin_Code+=+SHA', 'Destination_Code+=+CAN'], ['Flight_Date+=+2019-04-08', 'Destination+=+普吉', 'Ticket_Fee+=+476', 'Ticket_Fee+=+1000', 'Other_Fee+=+10', 'Total_Fee+=+1576', 'Destination_Code+=+HKT'], ['Name+=+余昌全', 'Flight_Number+=+TV988', 'Flight_Date+=+04-24', 'Origin+=+成都', 'Destination+=+拉萨', 'Ticket_Fee+=+1380.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1430.', 'Origin_Code+=+CTU', 'Destination_Code+=+LXA'], ['Name+=+LIANG/HUIBIN', 'Flight_Number+=+CZ8076', 'Flight_Date+=+05-09', 'Destination+=+武汉', 'Ticket_Fee+=+CNY490.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+钱琳', 'Flight_Number+=+HU7414', 'Flight_Date+=+05-16', 'Origin+=+太原', 'Destination+=+兰州', 'Ticket_Fee+=+CNY860.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY910.0', 'Origin_Code+=+TYN', 'Destination_Code+=+LHW'], ['Name+=+LAI/MINGJIE', 'Flight_Number+=+3U8626', 'Flight_Date+=+04-13', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+YDC', 'Destination_Code+=+DG', 'Destination_Code+=+XY'], ['Name+=+FANG/MIAO', 'Destination+=+晋江', 'Ticket_Fee+=+1240.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1290.', 'Origin_Code+=+LLF', 'Destination_Code+=+JN'], ['Name+=+DU/QIUE', 'Flight_Number+=+HU7935', 'Flight_Date+=+09-18', 'Origin+=+海口', 'Destination+=+澳门', 'Ticket_Fee+=+314.0', 'Total_Fee+=+11.7', 'Origin_Code+=+HAK', 'Destination_Code+=+MFM'], ['Name+=+ZHANG/SIRUI', 'Flight_Number+=+3U8925', 'Flight_Number+=+3U89', 'Flight_Number+=+3U8925', 'Flight_Date+=+07-15', 'Origin+=+成都', 'Destination+=+普吉', 'Develop_Fee+=+300.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+421.0', 'Origin_Code+=+CTU', 'Destination_Code+=+HKT'], ['Name+=+王琼秀', 'Flight_Number+=+CZ5145', 'Flight_Date+=+2018-09-29', 'Origin+=+南京', 'Destination+=+西安', 'Ticket_Fee+=+CNY760.0', 'Develop_Fee+=+CNY500', 'Oil_Fee+=+10.0', 'Total_Fee+=+CNY820.0', 'Origin_Code+=+NKG', 'Destination_Code+=+XIY'], ['Name+=+李瑜', 'Flight_Date+=+05-27', 'Origin+=+达县', 'Destination+=+深圳', 'Ticket_Fee+=+1430.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1480.0', 'Origin_Code+=+DAX', 'Destination_Code+=+SZX'], ['Name+=+张志兵', 'Flight_Number+=+1816', 'Flight_Date+=+10-18', 'Origin+=+厦门', 'Destination+=+北京', 'Ticket_Fee+=+120.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2170.', 'Origin_Code+=+XMN', 'Destination_Code+=+PEK'], ['Name+=+李伟挺', 'Flight_Number+=+7066', 'Flight_Number+=+HU7066', 'Flight_Number+=+7066', 'Flight_Number+=+HU7066', 'Flight_Date+=+12-29', 'Origin+=+厦门', 'Destination+=+深圳', 'Ticket_Fee+=+1300.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1350.', 'Origin_Code+=+XMN', 'Destination_Code+=+SZX'], ['Name+=+XU/XAOJING', 'Flight_Number+=+CZ8076', 'Flight_Number+=+7', 'Flight_Number+=+CZ8076', 'Flight_Number+=+7', 'Flight_Date+=+03-14', 'Destination+=+重庆', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HPG', 'Origin_Code+=+HPC', 'Destination_Code+=+CKG'], ['Name+=+刘伯隆', 'Flight_Number+=+1010', 'Flight_Date+=+07-02', 'Destination+=+咸阳', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+50', 'Oil_Fee+=+0.0', 'Other_Fee+=+164.0', 'Total_Fee+=+174.0', 'Origin_Code+=+GYU', 'Destination_Code+=+XY'], ['Name+=+TIAN/ZHUORONG', 'Flight_Date+=+05-06', 'Destination+=+重庆', 'Ticket_Fee+=+1200.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1200.', 'Origin_Code+=+LLB', 'Destination_Code+=+CKC'], ['Name+=+HUANG/JIAOXING', 'Flight_Number+=+CA4464', 'Flight_Date+=+05-13', 'Destination+=+成都', 'Ticket_Fee+=+1320.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1370.0', 'Origin_Code+=+PZI', 'Destination_Code+=+GNU'], ['Name+=+材东', 'Flight_Number+=+CZ9381', 'Flight_Date+=+2019-05-17', 'Origin+=+上海浦东', 'Destination+=+武汉', 'Ticket_Fee+=+2060.0', 'Develop_Fee+=+500', 'Oil_Fee+=+0', 'Total_Fee+=+60.2110.0', 'Origin_Code+=+PVG', 'Origin_Code+=+FIG', 'Destination_Code+=+WUH'], ['Name+=+孙小俊', 'Flight_Number+=+5608', 'Flight_Date+=+05-28', 'Origin+=+淮安', 'Destination+=+上海浦东', 'Ticket_Fee+=+510.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+560.0', 'Origin_Code+=+HIA', 'Destination_Code+=+PVG'], ['Name+=+LIU/HAIRONG', 'Flight_Number+=+G5254', 'Flight_Number+=+G', 'Flight_Number+=+G5254', 'Flight_Date+=+05-10', 'Destination+=+重庆', 'Ticket_Fee+=+750.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY750.0', 'Origin_Code+=+JHC', 'Destination_Code+=+CKG'], ['Name+=+许宸宇(童票)', 'Flight_Number+=+8133', 'Flight_Number+=+MF8133', 'Flight_Number+=+8133', 'Flight_Number+=+MF8133', 'Flight_Date+=+07-31', 'Origin+=+厦门', 'Destination+=+天津', 'Ticket_Fee+=+CNY700.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY700.0', 'Origin_Code+=+XMN', 'Destination_Code+=+TSN'], ['Name+=+张冬晨', 'Flight_Number+=+CZ3114', 'Flight_Number+=+C', 'Flight_Number+=+CZ3114', 'Flight_Date+=+07-22', 'Origin+=+北京', 'Destination+=+广州', 'Ticket_Fee+=+2640.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+PEK', 'Destination_Code+=+CAN'], ['Name+=+陈朝', 'Flight_Date+=+07-13', 'Origin+=+昆明', 'Destination+=+郑州', 'Ticket_Fee+=+7010', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+810.0', 'Origin_Code+=+KMG', 'Destination_Code+=+CGO'], ['Name+=+方义锋', 'Flight_Number+=+CA8906', 'Flight_Date+=+10-21', 'Origin+=+北京', 'Destination+=+大连', 'Ticket_Fee+=+1120.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1170.0', 'Origin_Code+=+PEK', 'Destination_Code+=+DLC'], ['Name+=+李丹', 'Flight_Number+=+ZH8310', 'Flight_Date+=+01-14', 'Origin+=+襄樊', 'Destination+=+珠海', 'Ticket_Fee+=+880.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+930.0', 'Origin_Code+=+XFN', 'Destination_Code+=+ZUH'], ['Name+=+赵建杰', 'Flight_Number+=+JR1527', 'Flight_Date+=+02-05', 'Origin+=+武汉', 'Destination+=+襄樊', 'Ticket_Fee+=+CNY350.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY350.0', 'Origin_Code+=+WUH', 'Destination_Code+=+XFN'], ['Name+=+钱琳', 'Flight_Number+=+9530', 'Flight_Date+=+03-21', 'Origin+=+温州', 'Destination+=+上海浦东', 'Ticket_Fee+=+550.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+600.0', 'Origin_Code+=+WN', 'Destination_Code+=+PVG'], ['Name+=+陈贤锋', 'Flight_Number+=+5454', 'Flight_Date+=+10-29', 'Origin+=+昆明', 'Destination+=+宁波', 'Ticket_Fee+=+1160.0', 'Develop_Fee+=+CN50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1210.0', 'Origin_Code+=+KMG', 'Destination_Code+=+NGB'], ['Name+=+ZHANG/SHUAI', 'Flight_Number+=+CZ8076', 'Flight_Date+=+05-20', 'Ticket_Fee+=+武汉', 'Ticket_Fee+=+404', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HPG', 'Origin_Code+=+HPC', 'Destination_Code+=+WUH'], ['Name+=+冯杰', 'Flight_Number+=+1083', 'Flight_Date+=+06-19', 'Origin+=+杭州', 'Destination+=+西宁', 'Ticket_Fee+=+1450.0', 'Total_Fee+=+C', 'Total_Fee+=+1500.0', 'Origin_Code+=+HGH', 'Destination_Code+=+XNN'], ['Name+=+许涛涛', 'Flight_Number+=+CZ3464', 'Origin+=+重庆', 'Destination+=+广州', 'Develop_Fee+=+50.0', 'Oil_Fee+=+30.0', 'Other_Fee+=+0.0', 'Total_Fee+=+310.0', 'Origin_Code+=+CKG', 'Destination_Code+=+CAN'], ['Name+=+WAN/SHUNQUIANG', 'Flight_Date+=+03-20', 'Destination+=+武汉', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+CHEN/PENG', 'Flight_Number+=+2966', 'Flight_Date+=+06-', 'Origin+=+珠海', 'Destination+=+长沙', 'Ticket_Fee+=+370.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+420.', 'Origin_Code+=+ZUH', 'Destination_Code+=+CSX'], ['Name+=+蔡品伦', 'Flight_Number+=+CZ3306', 'Flight_Date+=+03-04', 'Origin+=+宁波', 'Destination+=+南宁', 'Ticket_Fee+=+CNY1660.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.0', 'Total_Fee+=+CNY1710.0', 'Origin_Code+=+NGE', 'Destination_Code+=+NNG'], ['Name+=+杭定', 'Flight_Number+=+8L9911', 'Flight_Date+=+04-02', 'Origin+=+曼浊', 'Destination+=+是明', 'Ticket_Fee+=+770.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+820.0', 'Origin_Code+=+JHC', 'Destination_Code+=+KMG'], ['Name+=+侯光泰', 'Flight_Number+=+705', 'Flight_Date+=+11-06', 'Origin+=+深圳', 'Destination+=+上海虹桥', 'Ticket_Fee+=+1540.0', 'Oil_Fee+=+50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1640.0', 'Origin_Code+=+SZX', 'Destination_Code+=+SHA'], ['Name+=+王梓瑜(儿童票)', 'Flight_Number+=+MF8086', 'Flight_Date+=+08-01', 'Origin+=+大连', 'Destination+=+南京', 'Ticket_Fee+=+500.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+500.0', 'Origin_Code+=+DLC', 'Destination_Code+=+NKG'], ['Name+=+吴年娇', 'Flight_Number+=+MU5666', 'Flight_Date+=+08-08', 'Origin+=+厦门', 'Destination+=+上海虹桥', 'Ticket_Fee+=+1660.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1710.', 'Origin_Code+=+XMN', 'Destination_Code+=+SHA'], ['Name+=+陈露', 'Flight_Number+=+CZ3582', 'Flight_Date+=+07-19', 'Origin+=+上海虹桥', 'Destination+=+广州', 'Ticket_Fee+=+14605', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+O.0', 'Total_Fee+=+510.0', 'Origin_Code+=+SHA', 'Destination_Code+=+CAN'], ['Name+=+GCHEN/LIN', 'Flight_Number+=+CJ93', 'Flight_Date+=+20196-04', 'Destination+=+惠州', 'Ticket_Fee+=+520.00', 'Total_Fee+=+520.00', 'Origin_Code+=+HCJ'], ['Name+=+王梓瑜(儿童票)', 'Flight_Number+=+MF8086', 'Flight_Date+=+08-01', 'Origin+=+大连', 'Destination+=+南京', 'Ticket_Fee+=+500.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+500.0', 'Origin_Code+=+DLC', 'Destination_Code+=+NKG'], ['Name+=+陈春明', 'Flight_Number+=+Z6960', 'Flight_Date+=+06-25', 'Origin+=+咸阳', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+CNY7010', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+O.0', 'Total_Fee+=+830.0', 'Origin_Code+=+XIY', 'Destination_Code+=+URC'], ['Name+=+沙黄辉', 'Flight_Number+=+5244', 'Flight_Date+=+08-22', 'Origin+=+宁波', 'Destination+=+青岛', 'Ticket_Fee+=+CNY810.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+870.0', 'Origin_Code+=+NGB', 'Destination_Code+=+TAO'], ['Name+=+HOU/HAIRONGMS', 'Flight_Number+=+SC8885', 'Flight_Date+=+01-17', 'Origin+=+昆明', 'Destination+=+曼谷', 'Develop_Fee+=+90.0', 'Oil_Fee+=+200', 'Other_Fee+=+340.0', 'Origin_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+CHANG/JIALI', 'Flight_Number+=+MU5954', 'Flight_Date+=+06-28', 'Origin+=+腾冲', 'Destination+=+昆明', 'Ticket_Fee+=+1520.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1570.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG'], ['Name+=+杨会贤', 'Flight_Date+=+18-01', 'Origin+=+南阳', 'Destination+=+深圳', 'Ticket_Fee+=+1验', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+380.0', 'Origin_Code+=+NNY', 'Destination_Code+=+SZX'], ['Name+=+李嘉培', 'Flight_Number+=+9428', 'Flight_Date+=+04-26', 'Origin+=+重庆', 'Destination+=+深圳', 'Ticket_Fee+=+290.0', 'Develop_Fee+=+0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1340.0', 'Origin_Code+=+CKG', 'Destination_Code+=+SZX'], ['Name+=+杨璇', 'Flight_Number+=+CZ6', 'Flight_Date+=+05-25', 'Origin+=+乌鲁木齐', 'Destination+=+石家庄', 'Ticket_Fee+=+CNY1020.0', 'Develop_Fee+=+50.O', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.O', 'Origin_Code+=+UR', 'Destination_Code+=+SJW'], ['Name+=+叶秋慧', 'Flight_Number+=+GJ8759', 'Flight_Date+=+09-02', 'Origin+=+杭州', 'Destination+=+兰州', 'Ticket_Fee+=+CNY1930.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HGH', 'Destination_Code+=+LHW'], ['Name+=+黄智艺', 'Flight_Date+=+01-06', 'Origin+=+WMTWM', 'Destination+=+福州', 'Ticket_Fee+=+570.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY620.', 'Destination_Code+=+FOC'], ['Name+=+任玉柱', 'Flight_Number+=+MU2159', 'Flight_Date+=+11-12', 'Origin+=+延安', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+100.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+170.', 'Origin_Code+=+ENY', 'Destination_Code+=+XIY']]

# %%
entity_lls3 = [['Name+=+QIN/FEL', 'Flight_Number+=+MU537', 'Flight_Number+=+FM84', 'Flight_Number+=+MU537', 'Flight_Number+=+FM84', 'Flight_Date+=+24JUN', 'Origin+=+HPG', 'Destination+=+上海浦东', 'Destination+=+中院', 'Destination+=+曼谷口', 'Ticket_Fee+=+1200.00', 'Develop_Fee+=+40.00', 'Total_Fee+=+1830.00', 'Origin_Code+=+HPGT'], ['Name+=+杨帅杰', 'Flight_Number+=+GZ3881', 'Flight_Date+=+2019-04-18', 'Origin+=+珠海', 'Destination+=+杭州', 'Ticket_Fee+=+NY1310.0', 'Oil_Fee+=+50.', 'Total_Fee+=+1360.0', 'Origin_Code+=+ZUH', 'Destination_Code+=+HGH'], ['Name+=+张思睿', 'Flight_Number+=+8L9628', 'Flight_Date+=+07-15', 'Destination+=+成都', 'Ticket_Fee+=+1290.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1340.', 'Origin_Code+=+KGT', 'Destination_Code+=+CTU'], ['Name+=+LU0/SHAE', 'Flight_Number+=+7080', 'Flight_Date+=+201905-2', 'Origin_Code+=+LF0'], ['Name+=+任玉柱', 'Flight_Number+=+FU6692', 'Flight_Date+=+11-11', 'Origin+=+晋江', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+360.0', 'Develop_Fee+=+50.0', 'Other_Fee+=+0.0', 'Origin_Code+=+JN', 'Destination_Code+=+XEY'], ['Name+=+YU/JE', 'Flight_Number+=+G5265', 'Flight_Date+=+04-17', 'Origin+=+HCJ', 'Destination+=+桂林', 'Ticket_Fee+=+240.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+240.', 'Destination_Code+=+KWL'], ['Name+=+姜肖施', 'Flight_Number+=+CA1975', 'Flight_Date+=+2019.08', 'Origin+=+上海浦东', 'Destination+=+长春', 'Ticket_Fee+=+1350.00', 'Total_Fee+=+1400.00', 'Origin_Code+=+PVG', 'Origin_Code+=+CGQ'], ['Name+=+李静', 'Flight_Number+=+CZ6954', 'Flight_Date+=+09-14', 'Origin+=+石家庄', 'Destination+=+大连', 'Ticket_Fee+=+880.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+940.0', 'Origin_Code+=+SJW', 'Destination_Code+=+DLC'], ['Name+=+朱美', 'Name+=+伍金技', 'Name+=+魏兰', 'Origin+=+HPGHPGO', 'Destination+=+武汉', 'Ticket_Fee+=+320.00', 'Total_Fee+=+370.00', 'Destination_Code+=+5H'], ['Name+=+陈洪传', 'Flight_Date+=+01-06', 'Origin+=+WMTWM', 'Destination+=+福州', 'Ticket_Fee+=+570.0', 'Other_Fee+=+0.0', 'Total_Fee+=+620.', 'Destination_Code+=+FOC'], ['Name+=+FANG/HUAN', 'Flight_Number+=+3790', 'Flight_Date+=+05-13', 'Flight_Date+=+05-14', 'Origin+=+锡林浩特', 'Destination+=+南苑', 'Destination+=+北京', 'Ticket_Fee+=+40.0', 'Develop_Fee+=+曼谷', 'Develop_Fee+=+8.0', 'Origin_Code+=+XIL', 'Origin_Code+=+PEK', 'Destination_Code+=+NAY', 'Destination_Code+=+BKK'], ['Name+=+ZHANG/BIHUA', 'Flight_Number+=+8L9858', 'Flight_Number+=+8L801', 'Flight_Number+=+8L9858', 'Flight_Number+=+8L801', 'Flight_Date+=+07-14', 'Flight_Date+=+07-15', 'Origin+=+腾冲', 'Destination+=+昆明', 'Destination+=+曼谷', 'Develop_Fee+=+8.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+MIN/XUENON', 'Flight_Number+=+GJ8889', 'Flight_Number+=+GJ8800', 'Flight_Number+=+GJ8889', 'Flight_Number+=+GJ8800', 'Flight_Date+=+08-15', 'Flight_Date+=+08-21', 'Destination+=+咸阳', 'Destination+=+CXR', 'Develop_Fee+=+90.0', 'Oil_Fee+=+400.0', 'Other_Fee+=+110.0', 'Origin_Code+=+XTY', 'Destination_Code+=+CXRG', 'Destination_Code+=+XIY'], ['Name+=+ZHOU/XUAN', 'Flight_Date+=+05-17', 'Flight_Date+=+05-18', 'Destination+=+上海红桥', 'Destination+=+上海浦东', 'Destination+=+樊谷', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+WMT', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+于嘉', 'Flight_Number+=+GS7895', 'Flight_Date+=+04-08', 'Origin+=+天津', 'Destination+=+广州', 'Ticket_Fee+=+2490.0', 'Total_Fee+=+2540.0', 'Origin_Code+=+TSN', 'Destination_Code+=+CAN'], ['Name+=+刘焕', 'Flight_Number+=+MU5535', 'Flight_Date+=+07-15', 'Origin+=+武夷山', 'Destination+=+南宁', 'Ticket_Fee+=+CNY1220.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+WUS', 'Destination_Code+=+NNG'], ['Name+=+何燕华', 'Name+=+大鉴', 'Flight_Number+=+GH3436', 'Flight_Date+=+2019-11', 'Origin+=+贵阳', 'Destination+=+深圳', 'Ticket_Fee+=+1120.00', 'Total_Fee+=+1170.0', 'Destination_Code+=+SZX'], ['Name+=+徐永坡', 'Flight_Number+=+CZ6906', 'Flight_Date+=+2019-01-23', 'Origin+=+北京', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+740.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Oil_Fee+=+700.0', 'Total_Fee+=+1440.0', 'Origin_Code+=+PEK', 'Destination_Code+=+URC'], ['Name+=+黄彬强', 'Flight_Number+=+3U8378', 'Flight_Date+=+11-19', 'Origin+=+大连', 'Destination+=+徐州', 'Ticket_Fee+=+CNY1210.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+CNYYQ50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY1310.0', 'Origin_Code+=+DLC', 'Destination_Code+=+XUZ'], ['Name+=+10/CHA0', 'Flight_Number+=+ZH9920', 'Flight_Date+=+04-26', 'Origin+=+台州', 'Destination+=+深圳', 'Ticket_Fee+=+1140.00', 'Develop_Fee+=+50.00', 'Total_Fee+=+1190.00', 'Origin_Code+=+HYN', 'Destination_Code+=+SZX'], ['Name+=+庞杨', 'Flight_Date+=+08-03', 'Origin+=+天津', 'Destination+=+大连', 'Ticket_Fee+=+1960.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY2010.0', 'Origin_Code+=+TSN', 'Destination_Code+=+DLC'], ['Name+=+ZHANG/LI', 'Flight_Number+=+ZH9916', 'Flight_Number+=+ZH9001', 'Flight_Number+=+ZH9916', 'Flight_Number+=+ZH9001', 'Flight_Date+=+04-29', 'Flight_Date+=+04-30', 'Origin+=+青岛', 'Destination+=+深圳', 'Destination+=+曼谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+31.0', 'Origin_Code+=+TAO', 'Destination_Code+=+SZX', 'Destination_Code+=+BKK'], ['Name+=+YANG/XIANMING', 'Flight_Number+=+CZ3306', 'Flight_Date+=+01-21', 'Origin+=+宁波', 'Destination+=+南', 'Ticket_Fee+=+1660.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.0', 'Total_Fee+=+710.0', 'Origin_Code+=+NGB', 'Destination_Code+=+NNG'], ['Name+=+杜秋娥', 'Flight_Number+=+EU2231', 'Flight_Date+=+05-22', 'Origin+=+右洲', 'Origin+=+WMT', 'Destination+=+福州', 'Ticket_Fee+=+1300.0', 'Develop_Fee+=+CNYCN', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0', 'Destination_Code+=+FOC'], ['Name+=+HU/F合NGF', 'Name+=+武五', 'Flight_Number+=+6H0076', 'Flight_Date+=+201'], ['Name+=+CHEN/YANLI', 'Flight_Date+=+07-11', 'Origin+=+桂林', 'Destination+=+舌港', 'Develop_Fee+=+90.0', 'Oil_Fee+=+106.0', 'Other_Fee+=+0.0', 'Origin_Code+=+KWL', 'Destination_Code+=+HKG'], ['Flight_Number+=+9L42', 'Flight_Number+=+FM853S', 'Flight_Number+=+9L42', 'Flight_Number+=+FM853S', 'Flight_Date+=+21JUL', 'Destination+=+上海浦东', 'Destination+=+又鲁', 'Ticket_Fee+=+1430', 'Develop_Fee+=+140', 'Destination_Code+=+BKK'], ['Name+=+ZHOU/YUANXN', 'Flight_Number+=+CZ8303', 'Flight_Date+=+07-16', 'Flight_Date+=+07-17', 'Origin+=+郑州', 'Destination+=+三亚', 'Destination+=+曼谷', 'Ticket_Fee+=+1760.0', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+32.0', 'Origin_Code+=+CGC', 'Destination_Code+=+SYX', 'Destination_Code+=+BKK'], ['Name+=+苏静', 'Flight_Number+=+C', 'Origin+=+上海浦东', 'Origin+=+成都', 'Destination+=+上海浦东', 'Origin_Code+=+PVG', 'Origin_Code+=+CTU', 'Destination_Code+=+PVG'], ['Name+=+从庆', 'Flight_Number+=+3479', 'Origin+=+重庆', 'Origin+=+上海', 'Destination+=+南宁', 'Ticket_Fee+=+330.0', 'Oil_Fee+=+1O.0', 'Total_Fee+=+6Y390.0', 'Origin_Code+=+CKG'], ['Name+=+李哲', 'Flight_Number+=+6416', 'Flight_Date+=+2019-10-20', 'Origin+=+昆明', 'Destination+=+沈阳', 'Ticket_Fee+=+1120.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1170.0', 'Origin_Code+=+MG', 'Destination_Code+=+SHE'], ['Name+=+邓晓华', 'Flight_Number+=+CZ3487', 'Flight_Date+=+2019-04-19', 'Origin+=+广州', 'Destination+=+昆明', 'Ticket_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+CAN', 'Destination_Code+=+KMG'], ['Name+=+ZOU/PAN', 'Flight_Number+=+5580', 'Flight_Number+=+MU541', 'Flight_Number+=+5580', 'Flight_Number+=+MU541', 'Flight_Date+=+福州', 'Flight_Date+=+07-14', 'Flight_Date+=+上海浦东', 'Flight_Date+=+07-15', 'Origin+=+上海虹桥', 'Origin+=+曼谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+FOC', 'Origin_Code+=+PVG', 'Destination_Code+=+SHA', 'Destination_Code+=+BKK'], ['Name+=+XU/ZHE', 'Flight_Date+=+03-15', 'Destination+=+重庆', 'Ticket_Fee+=+560.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+610.0', 'Origin_Code+=+HPG', 'Destination_Code+=+CKG'], ['Name+=+钱琳', 'Flight_Number+=+5454', 'Flight_Date+=+04-22', 'Origin+=+昆明', 'Destination+=+宁波', 'Ticket_Fee+=+870.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+920.0', 'Origin_Code+=+KMC', 'Destination_Code+=+NGB'], ['Name+=+李智', 'Flight_Number+=+CZ6505', 'Flight_Number+=+C26502', 'Flight_Number+=+CZ6505', 'Flight_Number+=+C26502', 'Flight_Date+=+2019-11-13', 'Flight_Date+=+2019-11-15', 'Origin+=+沈阳', 'Destination+=+上海浦东', 'Destination+=+沈阳', 'Ticket_Fee+=+2100.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2200.0', 'Origin_Code+=+SHE', 'Destination_Code+=+PVG', 'Destination_Code+=+SHE'], ['Name+=+陈军委', 'Flight_Number+=+6434', 'Origin+=+08-02', 'Destination+=+杭州', 'Destination+=+沈阳', 'Ticket_Fee+=+1160.0', 'Total_Fee+=+1220.0', 'Origin_Code+=+HGH', 'Destination_Code+=+SHE'], ['Name+=+ZHAO/YONGMR', 'Flight_Number+=+5156', 'Flight_Date+=+07-11', 'Origin+=+北京', 'Destination+=+上海虹桥', 'Destination+=+上东', 'Destination+=+导谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+PEK', 'Origin_Code+=+PVG', 'Destination_Code+=+SHA', 'Destination_Code+=+BKK'], ['Name+=+董翔旭', 'Flight_Number+=+CZ3654', 'Origin+=+北京', 'Destination+=+贵阳', 'Ticket_Fee+=+72030.0', 'Ticket_Fee+=+1980.0', 'Develop_Fee+=+50-0', 'Oil_Fee+=+0.0', 'Origin_Code+=+EK', 'Destination_Code+=+KWE'], ['Name+=+李晶', 'Flight_Number+=+7429', 'Flight_Date+=+05-28', 'Origin+=+杭州', 'Destination+=+长春', 'Ticket_Fee+=+580.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0', 'Other_Fee+=+0.0', 'Total_Fee+=+630.0', 'Origin_Code+=+HGH', 'Destination_Code+=+CGO'], ['Name+=+任玉柱', 'Name+=+林伍通', 'Flight_Number+=+CZ6320', 'Flight_Date+=+2019-06-21', 'Origin+=+西安', 'Destination+=+三亚', 'Ticket_Fee+=+800.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+850.0', 'Origin_Code+=+XIY', 'Destination_Code+=+SYX'], ['Name+=+龚雪', 'Origin+=+腾冲', 'Destination+=+昆明', 'Ticket_Fee+=+12600', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1310.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG'], ['Name+=+黎武平', 'Flight_Number+=+8L9844', 'Flight_Date+=+01-11', 'Origin+=+南昌', 'Destination+=+赣州', 'Ticket_Fee+=+CNY940.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+EXEMPTYQ0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY990.0', 'Origin_Code+=+KHN', 'Destination_Code+=+KOW'], ['Flight_Number+=+C7833', 'Flight_Date+=+2019-05-16', 'Origin+=+文', 'Destination+=+武汉', 'Destination+=+昌谷', 'Ticket_Fee+=+832.', 'Oil_Fee+=+8.00', 'Destination_Code+=+HPG', 'Destination_Code+=+EKK'], ['Name+=+LU/YANG', 'Flight_Number+=+3U8112', 'Flight_Date+=+04-07', 'Destination+=+成都', 'Ticket_Fee+=+6900', 'Develop_Fee+=+500', 'Oil_Fee+=+0.0', 'Total_Fee+=+740.0', 'Origin_Code+=+CDC', 'Destination_Code+=+CTU'], ['Name+=+ZHANG/YUNJIN', 'Destination+=+武汉', 'Ticket_Fee+=+290.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+340.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+GINL/RLIDXIA', 'Flight_Number+=+GY7183', 'Flight_Date+=+00.20', 'Origin+=+八', 'Destination+=+成都', 'Ticket_Fee+=+640.00', 'Total_Fee+=+690.00', 'Origin_Code+=+LPF', 'Destination_Code+=+CTU'], ['Name+=+曾亦强', 'Flight_Number+=+FM9182', 'Flight_Date+=+06-05', 'Origin+=+张家界', 'Destination+=+揭阳潮汕', 'Ticket_Fee+=+480.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+530.0', 'Origin_Code+=+DYG', 'Destination_Code+=+SWA'], ['Name+=+钱琳', 'Flight_Number+=+MU2770', 'Flight_Date+=+04-13', 'Origin+=+咸阳', 'Destination+=+南京', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY820.', 'Origin_Code+=+XIY', 'Destination_Code+=+NKG'], ['Name+=+YANG/FENGMR', 'Flight_Number+=+2485', 'Flight_Date+=+06-28', 'Origin+=+武汉', 'Destination+=+昆明', 'Destination+=+曼谷', 'Develop_Fee+=+40.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+WUH', 'Destination_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+YE/TIANYOU', 'Flight_Number+=+CZ', 'Destination+=+武汉', 'Ticket_Fee+=+290.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+340.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+FU/WEIL', 'Flight_Number+=+CA413', 'Flight_Date+=+01-04', 'Origin+=+成都', 'Destination+=+普吉', 'Develop_Fee+=+CNYCN9O.O', 'Oil_Fee+=+CNYYO330.0', 'Other_Fee+=+CNYXT12.0', 'Origin_Code+=+CTU', 'Destination_Code+=+HKT'], ['Name+=+ZOU/HAO', 'Flight_Number+=+5206', 'Flight_Date+=+07-18', 'Origin+=+舟山', 'Destination+=+上海浦东', 'Destination+=+曼谷', 'Ticket_Fee+=+1690.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Total_Fee+=+2320.0', 'Origin_Code+=+HSN', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+陆班', 'Flight_Number+=+CA', 'Flight_Number+=+8363', 'Flight_Number+=+CA', 'Flight_Number+=+8363', 'Flight_Date+=+201812-26', 'Destination+=+昆明', 'Develop_Fee+=+50.00', 'Oil_Fee+=+0.00', 'Total_Fee+=+X910.00'], ['Name+=+王陈', 'Flight_Date+=+10-16', 'Origin+=+重庆', 'Destination+=+天津', 'Ticket_Fee+=+C', 'Ticket_Fee+=+577.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+657.0', 'Origin_Code+=+CKG', 'Destination_Code+=+TSN'], ['Name+=+王伊诺', 'Flight_Number+=+CG0069', 'Flight_Date+=+2019-02-14', 'Origin+=+郑州', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+280.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Oil_Fee+=+0', 'Total_Fee+=+280.0', 'Destination_Code+=+URC'], ['Name+=+PENG/DAJU', 'Flight_Number+=+MU28', 'Flight_Number+=+MU2860', 'Flight_Number+=+MU2860', 'Flight_Date+=+08-24', 'Flight_Date+=+08-28', 'Origin+=+南京', 'Destination+=+南京', 'Ticket_Fee+=+200.0', 'Ticket_Fee+=+626.0', 'Other_Fee+=+260.0', 'Total_Fee+=+3106.0', 'Origin_Code+=+NKG', 'Destination_Code+=+KANSA', 'Destination_Code+=+IKX', 'Destination_Code+=+NKG'], ['Name+=+化自成', 'Flight_Number+=+6', 'Flight_Date+=+2019-1-58', 'Origin+=+上海浦东', 'Origin+=+大连', 'Ticket_Fee+=+670.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+00', 'Total_Fee+=+720', 'Origin_Code+=+DLC'], ['Name+=+ZHANGYUNJIN', 'Destination+=+西投', 'Origin_Code+=+HPG'], ['Name+=+MO/YANAN', 'Flight_Number+=+MU73', 'Flight_Number+=+MU74', 'Flight_Number+=+MU7402', 'Flight_Number+=+MU73', 'Flight_Number+=+MU7402', 'Flight_Date+=+07-23', 'Flight_Date+=+08-10', 'Origin+=+上海浦东', 'Destination+=+墨尔本', 'Destination+=+上海浦东', 'Develop_Fee+=+0.0', 'Oil_Fee+=+286.0', 'Other_Fee+=+1675.0', 'Origin_Code+=+PVG', 'Destination_Code+=+MEL', 'Destination_Code+=+PVG'], ['Name+=+王楷然', 'Flight_Number+=+26696', 'Flight_Date+=+201903-18', 'Origin+=+富蕴', 'Destination+=+马鲁木齐', 'Ticket_Fee+=+270.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+320.0', 'Origin_Code+=+FYN', 'Destination_Code+=+URC'], ['Name+=+LIU/YUAN', 'Flight_Number+=+G52694', 'Flight_Date+=+2019-04-23', 'Destination+=+贵阳', 'Ticket_Fee+=+60.00', 'Origin_Code+=+HC', 'Origin_Code+=+HCJ'], ['Name+=+于嘉', 'Flight_Number+=+G57896', 'Flight_Date+=+04-08', 'Origin+=+广州', 'Destination+=+天津', 'Ticket_Fee+=+1630.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1680.0', 'Origin_Code+=+CAN', 'Destination_Code+=+TSN'], ['Name+=+PFNG/SANMEI', 'Flight_Number+=+MU281', 'Flight_Date+=+26NOV', 'Ticket_Fee+=+2100', 'Other_Fee+=+428.00', 'Total_Fee+=+2618.00', 'Destination_Code+=+SGN'], ['Name+=+余涛', 'Flight_Number+=+CZ6954', 'Flight_Date+=+2018-11-25', 'Origin+=+石家庄', 'Destination+=+大连', 'Ticket_Fee+=+20.0', 'Total_Fee+=+520.0', 'Total_Fee+=+450', 'Destination_Code+=+DLC'], ['Name+=+李影南', 'Flight_Number+=+GJ8759', 'Flight_Date+=+09-02', 'Origin+=+杭州', 'Destination+=+兰州', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HGH', 'Destination_Code+=+LHW'], ['Name+=+陈会', 'Flight_Number+=+0Z364', 'Flight_Date+=+2019-04-12', 'Origin+=+柒江', 'Origin+=+西安', 'Ticket_Fee+=+680.0', 'Develop_Fee+=+50', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY730.0', 'Origin_Code+=+ZA'], ['Name+=+吴年娇', 'Flight_Number+=+CA1816', 'Flight_Date+=+10-18', 'Origin+=+厦门', 'Destination+=+北京', 'Ticket_Fee+=+2120.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2170.', 'Origin_Code+=+XMN', 'Destination_Code+=+PEK'], ['Name+=+国伍', 'Name+=+L有章', 'Flight_Number+=+CZ6093', 'Flight_Date+=+18MAY', 'Origin+=+北京', 'Destination+=+普吉', 'Ticket_Fee+=+1738.00', 'Origin_Code+=+ZHANG', 'Origin_Code+=+FENMS'], ['Name+=+蔡品伦', 'Flight_Number+=+EU2278', 'Flight_Date+=+03-19', 'Origin+=+温州', 'Destination+=+武汉', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY820.0', 'Origin_Code+=+WNZ', 'Destination_Code+=+WUH'], ['Name+=+张玉林', 'Flight_Number+=+ZH9334', 'Flight_Date+=+12-23', 'Origin+=+福州', 'Destination+=+郑州', 'Ticket_Fee+=+1250.0', 'Total_Fee+=+CNY1300.', 'Origin_Code+=+FOC'], ['Name+=+余益添', 'Flight_Number+=+MF1018', 'Flight_Date+=+08-28', 'Origin+=+广州', 'Destination+=+杭州', 'Ticket_Fee+=+1410.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1460.0', 'Origin_Code+=+CAN', 'Destination_Code+=+HGH'], ['Name+=+黄智艺', 'Flight_Date+=+01-06', 'Origin+=+WMTWM', 'Destination+=+福州', 'Ticket_Fee+=+570.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY620.', 'Destination_Code+=+FOC'], ['Name+=+LAI/SHUTINGMS', 'Flight_Number+=+MU2071', 'Flight_Date+=+07-03', 'Origin+=+北京', 'Destination+=+上海靖', 'Ticket_Fee+=+1320.0', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Total_Fee+=+1950.0', 'Origin_Code+=+PEK', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+CHEN/PENG', 'Flight_Number+=+MU2966', 'Flight_Date+=+06-19', 'Origin+=+珠海', 'Destination+=+长沙', 'Ticket_Fee+=+370.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY420.0', 'Origin_Code+=+ZUH', 'Destination_Code+=+CSX'], ['Name+=+YU/J1NJ11MS', 'Flight_Number+=+D2892', 'Flight_Date+=+2019-04', 'Origin+=+厂州', 'Destination+=+清通', 'Destination_Code+=+CX0'], ['Name+=+朱永秀', 'Flight_Number+=+CZ3828', 'Flight_Date+=+2019-08-25', 'Origin+=+南京', 'Destination+=+深圳', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+C', 'Total_Fee+=+50.0', 'Origin_Code+=+NKG', 'Destination_Code+=+SZX'], ['Name+=+钱琳', 'Flight_Number+=+7414', 'Flight_Number+=+HU7414', 'Flight_Number+=+7414', 'Flight_Number+=+HU7414', 'Flight_Date+=+05-16', 'Origin+=+宁波', 'Destination+=+太原', 'Ticket_Fee+=+CNY800.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY850.0', 'Origin_Code+=+NGB', 'Destination_Code+=+TYN'], ['Flight_Date+=+2018-09-17', 'Origin+=+ZHANG', 'Origin+=+武汉', 'Destination_Code+=+MFM'], ['Name+=+钱琳', 'Flight_Number+=+9', 'Flight_Number+=+MU9614', 'Flight_Number+=+9', 'Flight_Number+=+MU9614', 'Flight_Date+=+04-13', 'Origin+=+烟台', 'Destination+=+咸阳', 'Ticket_Fee+=+720.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY', 'Total_Fee+=+770', 'Origin_Code+=+YNT', 'Destination_Code+=+XIY'], ['Name+=+YAN/HONGOIONGMS', 'Flight_Number+=+8L9710', 'Flight_Number+=+8L809', 'Flight_Number+=+8L9710', 'Flight_Number+=+8L809', 'Flight_Date+=+05-19', 'Flight_Date+=+05-20', 'Destination+=+昆明', 'Destination+=+清迈', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+332.0', 'Origin_Code+=+LCX', 'Destination_Code+=+KMG', 'Destination_Code+=+CNX'], ['Name+=+张志兵', 'Flight_Number+=+MU5708', 'Flight_Date+=+08-11', 'Origin+=+北京', 'Destination+=+昆明', 'Ticket_Fee+=+C', 'Develop_Fee+=+50', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1710.', 'Origin_Code+=+PEK', 'Destination_Code+=+KMG'], ['Name+=+CHEN/XIANGBO', 'Flight_Number+=+3718', 'Flight_Date+=+06-07', 'Flight_Date+=+06-08', 'Origin+=+呼和浩特', 'Destination+=+宁波', 'Destination+=+曼谷', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Total_Fee+=+482.0', 'Origin_Code+=+HET', 'Destination_Code+=+NGB', 'Destination_Code+=+BKK'], ['Name+=+9FEI/RUILAN', 'Flight_Number+=+CA831', 'Flight_Date+=+09-14', 'Origin+=+北京', 'Destination+=+冲绳', 'Ticket_Fee+=+310.0', 'Develop_Fee+=+90.0', 'Other_Fee+=+0.0', 'Origin_Code+=+PEK国', 'Destination_Code+=+OKA'], ['Name+=+WANG/YI', 'Flight_Number+=+5546', 'Flight_Date+=+07-07', 'Flight_Date+=+07-08', 'Origin+=+烟台', 'Destination+=+上海浦东', 'Destination+=+曼谷', 'Develop_Fee+=+0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+YNT', 'Destination_Code+=+PVG', 'Destination_Code+=+BKK'], ['Name+=+杨振', 'Flight_Date+=+05-18', 'Origin+=+北京', 'Destination+=+杭州', 'Ticket_Fee+=+CNY2200.0', 'Develop_Fee+=+CNY', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+2250.0', 'Origin_Code+=+PEK', 'Destination_Code+=+HG'], ['Name+=+委彦波', 'Flight_Number+=+GS7657', 'Flight_Date+=+01-06', 'Origin+=+咸阳', 'Destination+=+南京', 'Ticket_Fee+=+500.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+Q.0', 'Other_Fee+=+0.0', 'Total_Fee+=+550.0', 'Origin_Code+=+XY', 'Destination_Code+=+NKG'], ['Flight_Number+=+HX161', 'Flight_Date+=+08-30', 'Flight_Date+=+09-01', 'Origin+=+香港', 'Destination+=+三亚', 'Destination+=+香港', 'Ticket_Fee+=+16', 'Oil_Fee+=+81.0', 'Total_Fee+=+108', 'Origin_Code+=+HKG', 'Destination_Code+=+SYX', 'Destination_Code+=+HKG'], ['Name+=+HU/JIALI', 'Flight_Number+=+MU73', 'Flight_Number+=+MU74', 'Flight_Number+=+MU7402', 'Flight_Number+=+MU73', 'Flight_Number+=+MU7402', 'Flight_Date+=+07-23', 'Flight_Date+=+08-10', 'Origin+=+上海浦东', 'Destination+=+尔本', 'Destination+=+上海浦东', 'Develop_Fee+=+90.0', 'Oil_Fee+=+286.0', 'Total_Fee+=+1675.0', 'Origin_Code+=+PVG', 'Destination_Code+=+MEL', 'Destination_Code+=+PVG'], ['Name+=+蔡品伦', 'Flight_Number+=+9830', 'Flight_Date+=+01-12', 'Origin+=+长春', 'Destination+=+烟台', 'Ticket_Fee+=+320.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+CGQ', 'Destination_Code+=+YNT'], ['Name+=+詹萌', 'Flight_Number+=+CZ6581', 'Flight_Number+=+CZ6452', 'Flight_Number+=+CZ6581', 'Flight_Number+=+CZ6452', 'Flight_Date+=+2019-10-11', 'Flight_Date+=+2019-10-13', 'Origin+=+沈阳', 'Destination+=+南京', 'Destination+=+沈阳', 'Ticket_Fee+=+1240.0', 'Develop_Fee+=+100.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1340.0', 'Origin_Code+=+SHE', 'Destination_Code+=+NKG', 'Destination_Code+=+SHE'], ['Name+=+ZHANG/MINGHE', 'Flight_Number+=+8L9984', 'Flight_Number+=+8L801', 'Flight_Number+=+8L9984', 'Flight_Number+=+8L801', 'Flight_Date+=+07-02', 'Flight_Date+=+07-03', 'Origin+=+咸阳', 'Destination+=+昆明', 'Destination+=+曼谷', 'Oil_Fee+=+8.0', 'Other_Fee+=+232.0', 'Origin_Code+=+XIY', 'Destination_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+潘志金', 'Origin+=+广州', 'Destination+=+昆明', 'Ticket_Fee+=+1050.0', 'Develop_Fee+=+0.0', 'Total_Fee+=+67100.0', 'Destination_Code+=+KMG'], ['Name+=+解庆锋', 'Flight_Number+=+C7818', 'Flight_Date+=+2018-10-29', 'Origin+=+杭州', 'Destination+=+重庆', 'Ticket_Fee+=+900.0', 'Develop_Fee+=+50.O', 'Oil_Fee+=+10.0', 'Total_Fee+=+960.0', 'Origin_Code+=+HGH', 'Destination_Code+=+CKG'], ['Name+=+谈亚强', 'Flight_Date+=+08-09', 'Origin+=+上海浦东', 'Destination+=+重庆', 'Ticket_Fee+=+960.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY1020', 'Origin_Code+=+PVG', 'Destination_Code+=+CKG'], ['Name+=+张瑞娟', 'Flight_Number+=+GS', 'Flight_Date+=+10-16', 'Origin+=+重庆', 'Destination+=+天津', 'Ticket_Fee+=+577.0', 'Oil_Fee+=+30.', 'Total_Fee+=+CNY657.0', 'Origin_Code+=+CKG', 'Destination_Code+=+TSN'], ['Name+=+李风兰', 'Origin+=+徐州', 'Destination+=+哈尔滨', 'Ticket_Fee+=+2090.0', 'Develop_Fee+=+5O.O', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+2140.0', 'Origin_Code+=+XUZ', 'Destination_Code+=+HRB'], ['Name+=+赵玉双', 'Name+=+木杰', 'Flight_Number+=+CZ6714', 'Flight_Date+=+07-05', 'Ticket_Fee+=+CNY1650.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+PEK', 'Destination_Code+=+SYX'], ['Name+=+张舒冬', 'Flight_Number+=+CZ6709', 'Flight_Date+=+2019-04-1712-35', 'Origin+=+厦门', 'Destination+=+大连', 'Ticket_Fee+=+1590.00', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1640.0', 'Origin_Code+=+XMN', 'Destination_Code+=+DLC'], ['Name+=+YU/LIANG', 'Flight_Number+=+G52654', 'Flight_Date+=+03-21', 'Origin+=+HC', 'Destination+=+桂林', 'Ticket_Fee+=+180.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+230.0', 'Origin_Code+=+HCJ', 'Destination_Code+=+KWL'], ['Name+=+冯杰', 'Flight_Number+=+EU281', 'Flight_Date+=+05-02', 'Destination+=+哈尔滨', 'Ticket_Fee+=+CNY500.0', 'Total_Fee+=+CNY500.0', 'Origin_Code+=+DTU', 'Destination_Code+=+HRB'], ['Name+=+谢明有', 'Destination+=+成都', 'Ticket_Fee+=+1480.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1530.0', 'Origin_Code+=+LZY', 'Destination_Code+=+CTU'], ['Name+=+TANG/KEMR', 'Flight_Date+=+05-18', 'Origin+=+武汉', 'Destination+=+广州', 'Destination+=+曼谷', 'Ticket_Fee+=+CNY1670.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+32.0', 'Total_Fee+=+CNY', 'Total_Fee+=+1850.0', 'Origin_Code+=+WUH', 'Destination_Code+=+CAN', 'Destination_Code+=+BKK'], ['Name+=+强刚', 'Flight_Number+=+9148', 'Flight_Number+=+FM9148', 'Flight_Number+=+9148', 'Flight_Number+=+FM9148', 'Flight_Date+=+03-11', 'Origin+=+天津', 'Destination+=+上海虹桥', 'Ticket_Fee+=+2110.0', 'Develop_Fee+=+0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2160.', 'Origin_Code+=+TSN', 'Destination_Code+=+SHA'], ['Name+=+工有', 'Flight_Date+=+23AUG', 'Destination+=+C', 'Total_Fee+=+4878.00', 'Destination_Code+=+CJU'], ['Name+=+齐湖', 'Flight_Number+=+DJ0517', 'Origin+=+三亚', 'Destination+=+西安', 'Ticket_Fee+=+800.00', 'Develop_Fee+=+50:00', 'Oil_Fee+=+0:00', 'Total_Fee+=+850.00', 'Origin_Code+=+XIY'], ['Name+=+ZHANG/LU', 'Flight_Number+=+G5265', 'Flight_Date+=+05-10', 'Destination+=+桂林', 'Ticket_Fee+=+120.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+120.', 'Origin_Code+=+HCJ', 'Destination_Code+=+KWL'], ['Name+=+CHENG/FAKE', 'Flight_Number+=+2262', 'Flight_Date+=+06-22', 'Origin+=+湛江', 'Destination+=+重庆', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+900.0', 'Origin_Code+=+ZHA', 'Destination_Code+=+CKG'], ['Name+=+刘发贵', 'Flight_Number+=+6950', 'Flight_Date+=+03-12', 'Origin+=+昆明', 'Destination+=+重庆', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.0', 'Total_Fee+=+50.0', 'Origin_Code+=+KMC', 'Destination_Code+=+CKG'], ['Name+=+陈素珍', 'Flight_Date+=+07.07', 'Destination+=+桂林', 'Ticket_Fee+=+180.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+180.0', 'Origin_Code+=+HCJ', 'Destination_Code+=+KWL'], ['Name+=+李姝', 'Origin+=+上海浦东', 'Origin+=+长春', 'Destination+=+上海浦', 'Ticket_Fee+=+1000.0', 'Develop_Fee+=+0.50', 'Total_Fee+=+6.10', 'Total_Fee+=+50.0', 'Origin_Code+=+PVG', 'Origin_Code+=+CGQ'], ['Name+=+王浩', 'Flight_Number+=+8L9870', 'Flight_Date+=+06-20', 'Origin+=+青岛', 'Destination+=+武汉', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+TAO', 'Destination_Code+=+WUH'], ['Name+=+任玉柱', 'Flight_Number+=+FU6691', 'Flight_Date+=+11-11', 'Origin+=+咸阳', 'Destination+=+晋江', 'Ticket_Fee+=+370.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+XYF', 'Destination_Code+=+JN'], ['Name+=+ZENG/CHAO', 'Flight_Number+=+G52654', 'Flight_Date+=+07-01', 'Destination+=+重庆', 'Ticket_Fee+=+CNY430.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+O.0', 'Total_Fee+=+430.0', 'Destination_Code+=+CKG', 'Destination_Code+=+XXX'], ['Name+=+陈希东', 'Flight_Number+=+CZ6128', 'Flight_Date+=+2019-08-09', 'Origin+=+北京', 'Destination+=+大连', 'Ticket_Fee+=+CNY1120.0', 'Develop_Fee+=+CNY50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1170.0', 'Origin_Code+=+PEK', 'Destination_Code+=+DLC'], ['Name+=+冯涛', 'Flight_Number+=+MU2314', 'Flight_Date+=+07-16', 'Origin+=+西宁', 'Destination+=+成阳', 'Ticket_Fee+=+CNY330.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY380.0', 'Origin_Code+=+XNN', 'Destination_Code+=+XIY'], ['Name+=+晏涨龙', 'Flight_Date+=+11-22', 'Origin+=+贵阳', 'Destination+=+六盘水', 'Ticket_Fee+=+CNY30.0', 'Develop_Fee+=+NYCN50.', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY280.', 'Origin_Code+=+KWE', 'Destination_Code+=+LPF'], ['Name+=+丁治祥', 'Flight_Number+=+CZ3595', 'Origin+=+广州', 'Destination+=+上海虹桥', 'Ticket_Fee+=+1820', 'Ticket_Fee+=+1980.00', 'Oil_Fee+=+O.6', 'Origin_Code+=+CAN', 'Destination_Code+=+SHA'], ['Name+=+化世南', 'Flight_Number+=+7988', 'Flight_Date+=+12-30', 'Destination+=+西安', 'Destination+=+天津', 'Ticket_Fee+=+0030.00', 'Develop_Fee+=+50.00', 'Oil_Fee+=+0.0', 'Destination_Code+=+XY6', 'Destination_Code+=+TSN'], ['Name+=+郭念', 'Flight_Number+=+90', 'Flight_Date+=+12-10', 'Origin+=+广州', 'Ticket_Fee+=+1390.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1440.', 'Origin_Code+=+CAN', 'Destination_Code+=+WUX'], ['Name+=+CHEN/LIANLI', 'Flight_Number+=+ZH8916', 'Flight_Date+=+05-17', 'Origin+=+三亚', 'Destination+=+惠州', 'Ticket_Fee+=+CNY480.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY530.0', 'Origin_Code+=+SYX', 'Destination_Code+=+HUZ'], ['Flight_Number+=+3U8600', 'Flight_Date+=+2019-05-23', 'Destination+=+西安成阳', 'Ticket_Fee+=+800.00', 'Develop_Fee+=+5Q.O', 'Oil_Fee+=+0', 'Total_Fee+=+0.00'], ['Name+=+张玉林', 'Flight_Number+=+JR1463', 'Flight_Date+=+11-23', 'Origin+=+武汉', 'Destination+=+揭阳潮油', 'Ticket_Fee+=+CN450.0', 'Develop_Fee+=+CN50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY500.0', 'Origin_Code+=+WUH', 'Destination_Code+=+SWA'], ['Name+=+林岳铨', 'Flight_Number+=+CZ369R', 'Flight_Date+=+2018-12', 'Origin+=+南京', 'Destination+=+广州', 'Ticket_Fee+=+CNY1440.0', 'Develop_Fee+=+CNY50.0', 'Oil_Fee+=+CNY50.0', 'Origin_Code+=+NKG', 'Destination_Code+=+CAN'], ['Flight_Date+=+2019-04-08', 'Destination+=+普吉', 'Ticket_Fee+=+476', 'Ticket_Fee+=+1000', 'Other_Fee+=+10', 'Total_Fee+=+1576', 'Destination_Code+=+HKT'], ['Name+=+赵建杰', 'Name+=+木得', 'Flight_Number+=+A01145', 'Flight_Date+=+2019-03-11', 'Origin+=+贵阳龙汇堡', 'Destination+=+宜昌', 'Destination+=+三峡', 'Ticket_Fee+=+30900', 'Develop_Fee+=+50.00', 'Oil_Fee+=+0,00', 'Total_Fee+=+0.00', 'Total_Fee+=+71.250.0', 'Origin_Code+=+KWE'], ['Name+=+程英华', 'Flight_Number+=+CZ8076', 'Flight_Date+=+2019-05-20', 'Origin+=+神农架', 'Destination+=+武汉', 'Ticket_Fee+=+0.0', 'Total_Fee+=+CNY0.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+黄彬强', 'Flight_Number+=+CA8938', 'Flight_Date+=+11-17', 'Destination+=+大连', 'Ticket_Fee+=+CNY1210.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+CNYYQ50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY1310.0', 'Origin_Code+=+WDS', 'Destination_Code+=+DLC'], ['Name+=+瞿槿芊(童票)', 'Flight_Number+=+98', 'Flight_Date+=+04-18', 'Origin+=+南京', 'Destination+=+广州', 'Ticket_Fee+=+720.0', 'Other_Fee+=+0.0', 'Total_Fee+=+720.', 'Origin_Code+=+NKG', 'Destination_Code+=+CAN'], ['Name+=+龚坚', 'Flight_Number+=+64', 'Flight_Date+=+05-16', 'Origin+=+南京', 'Destination+=+南宁', 'Ticket_Fee+=+1000.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1050.0', 'Origin_Code+=+NKG', 'Destination_Code+=+NN'], ['Name+=+晁汐(南通)', 'Flight_Number+=+3U822', 'Flight_Number+=+3U8220', 'Flight_Number+=+3U8220', 'Flight_Date+=+03-10', 'Destination+=+武汉', 'Ticket_Fee+=+680.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+730.0', 'Origin_Code+=+HPG', 'Origin_Code+=+HPC', 'Destination_Code+=+WUH'], ['Name+=+卢云恺', 'Flight_Number+=+CZ6599', 'Flight_Date+=+2019-0217', 'Origin+=+郑州', 'Destination+=+鄂尔多斯', 'Ticket_Fee+=+CNY0.0', 'Develop_Fee+=+CNY0.0', 'Oil_Fee+=+CNY0.0', 'Total_Fee+=+CNY0.0', 'Origin_Code+=+CG0', 'Destination_Code+=+DSN'], ['Name+=+陆效', 'Name+=+何成', 'Flight_Number+=+C76954', 'Flight_Date+=+1208', 'Origin+=+石家庄', 'Destination+=+董连', 'Ticket_Fee+=+880.00', 'Develop_Fee+=+5000', 'Oil_Fee+=+0.00', 'Total_Fee+=+940.0', 'Total_Fee+=+0.70', 'Origin_Code+=+SJW', 'Destination_Code+=+DLC'], ['Origin+=+中', 'Origin+=+HPGHPG', 'Destination+=+邵郑', 'Destination+=+武汉', 'Ticket_Fee+=+320.00', 'Total_Fee+=+370.00'], ['Name+=+日', 'Flight_Number+=+CZB076', 'Flight_Date+=+03+16', 'Origin+=+神农渠', 'Destination+=+重庆', 'Ticket_Fee+=+850.00', 'Develop_Fee+=+500', 'Oil_Fee+=+0', 'Total_Fee+=+900.00', 'Origin_Code+=+HPG', 'Destination_Code+=+CKG'], ['Name+=+陈忠达', 'Flight_Number+=+FM9526', 'Flight_Date+=+06-09', 'Origin+=+温州', 'Destination+=+上海浦东', 'Ticket_Fee+=+CN', 'Ticket_Fee+=+1430.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1480.0', 'Origin_Code+=+WNZ', 'Destination_Code+=+PVG'], ['Name+=+冯杰', 'Flight_Number+=+FM9244', 'Flight_Date+=+07-22', 'Origin+=+黄山', 'Destination+=+温州', 'Ticket_Fee+=+520.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+570.0', 'Origin_Code+=+TXN', 'Destination_Code+=+WNZ'], ['Name+=+杨颖', 'Flight_Number+=+ZH831', 'Flight_Date+=+01-14', 'Origin+=+襄樊', 'Destination+=+珠海', 'Ticket_Fee+=+CNY880.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY930.0', 'Origin_Code+=+XFN', 'Destination_Code+=+ZUH'], ['Name+=+谢志红', 'Flight_Number+=+CZ3373', 'Flight_Date+=+2019-08-13', 'Origin+=+广州', 'Destination+=+西宁', 'Ticket_Fee+=+1320.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1370.0', 'Origin_Code+=+CAN', 'Destination_Code+=+XN'], ['Name+=+刘小锋', 'Flight_Number+=+Y87506', 'Flight_Date+=+12-21', 'Origin+=+武汉', 'Destination+=+上海浦', 'Ticket_Fee+=+300.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+360.0', 'Origin_Code+=+WUH'], ['Name+=+HU/HONGXIA', 'Flight_Number+=+CZ6387', 'Flight_Date+=+01-02', 'Origin+=+图里TOT', 'Origin+=+上海浦东', 'Ticket_Fee+=+CNY350.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+30.0', 'Other_Fee+=+0.0', 'Total_Fee+=+430.0', 'Origin_Code+=+KWE', 'Destination_Code+=+PV'], ['Name+=+YANG/JIAN', 'Flight_Number+=+FM831', 'Flight_Date+=+05-23', 'Origin+=+珠海', 'Origin+=+上海虹桥', 'Destination+=+上海浦东', 'Destination+=+普', 'Develop_Fee+=+140.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+482.0', 'Origin_Code+=+ZUH', 'Origin_Code+=+PVG', 'Destination_Code+=+SHA', 'Destination_Code+=+HKT'], ['Name+=+刘燕芳', 'Flight_Number+=+C23380', 'Flight_Date+=+20190622', 'Origin+=+广州', 'Destination+=+长沙', 'Ticket_Fee+=+1260.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Total_Fee+=+1310.0', 'Origin_Code+=+CAN', 'Destination_Code+=+CSX'], ['Name+=+吴年娇', 'Flight_Number+=+JR14', 'Flight_Date+=+11-23', 'Origin+=+武汉', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+345.0', 'Develop_Fee+=+5', 'Oil_Fee+=+0.0', 'Total_Fee+=+395.0', 'Origin_Code+=+WUH', 'Destination_Code+=+XY'], ['Name+=+刘爱霞', 'Flight_Number+=+2918', 'Flight_Date+=+08-01', 'Origin+=+广州', 'Ticket_Fee+=+1540.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1590.0', 'Origin_Code+=+CAN', 'Destination_Code+=+WWUX'], ['Name+=+纪丽', 'Flight_Number+=+5769', 'Flight_Number+=+MU5769', 'Flight_Number+=+5769', 'Flight_Number+=+MU5769', 'Flight_Date+=+07-01', 'Origin+=+腾冲', 'Destination+=+成都', 'Ticket_Fee+=+CNY1200.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+00', 'Other_Fee+=+0.0', 'Total_Fee+=+1250.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+CTU'], ['Name+=+WANG/JICHAO', 'Flight_Number+=+MU5634', 'Flight_Number+=+MU9857', 'Flight_Number+=+MU5634', 'Flight_Number+=+MU9857', 'Flight_Date+=+03-20', 'Flight_Date+=+03-21', 'Origin+=+乌鲁木齐', 'Destination+=+上海虹桥', 'Destination+=+上海浦东', 'Ticket_Fee+=+CNY4114.0', 'Develop_Fee+=+CNYCN0', 'Oil_Fee+=+CNY', 'Oil_Fee+=+8.0', 'Other_Fee+=+481.0', 'Total_Fee+=+4743.0', 'Origin_Code+=+URC', 'Destination_Code+=+SHA', 'Destination_Code+=+PVG'], ['Name+=+贺晓杰', 'Flight_Number+=+TV6011', 'Flight_Date+=+07-11', 'Origin+=+太原', 'Destination+=+烟台', 'Ticket_Fee+=+670.0', 'Develop_Fee+=+CNYCN5O.O', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+730.0', 'Origin_Code+=+TYN', 'Destination_Code+=+YNT'], ['Name+=+李琳卫', 'Name+=+余菊香', 'Flight_Number+=+MU5372', 'Flight_Date+=+05-18', 'Origin+=+武汉', 'Destination+=+上海浦东', 'Ticket_Fee+=+CNY870.0', 'Develop_Fee+=+C', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY920.0', 'Origin_Code+=+WUH', 'Destination_Code+=+PVG'], ['Name+=+何杰', 'Flight_Number+=+CZ6818', 'Flight_Date+=+2018-11-2511:50', 'Origin+=+和田', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+HTN', 'Destination_Code+=+URC'], ['Name+=+戴萍', 'Flight_Number+=+CZ6997', 'Flight_Date+=+2019-01-27', 'Origin+=+喀什', 'Destination+=+上海虹桥', 'Ticket_Fee+=+2950.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY', 'Total_Fee+=+3000.0', 'Origin_Code+=+KHG', 'Destination_Code+=+SHA'], ['Name+=+吴定韵', 'Flight_Number+=+9505', 'Flight_Date+=+09-17', 'Origin+=+长春', 'Destination+=+烟台', 'Ticket_Fee+=+630.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+690.0', 'Origin_Code+=+CGQ', 'Destination_Code+=+YNT'], ['Name+=+石祚宝', 'Flight_Number+=+2918', 'Flight_Date+=+08-01', 'Origin+=+广州', 'Ticket_Fee+=+1540.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1590.0', 'Origin_Code+=+CAN', 'Destination_Code+=+WUX'], ['Name+=+杨苏元', 'Flight_Number+=+MU5661', 'Flight_Date+=+08-22', 'Origin+=+上海浦东', 'Destination+=+大连', 'Ticket_Fee+=+730.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+790.0', 'Origin_Code+=+PVG', 'Destination_Code+=+DLC'], ['Name+=+陈巍', 'Flight_Number+=+SC4696', 'Flight_Date+=+12-02', 'Origin+=+南京', 'Destination+=+青岛', 'Ticket_Fee+=+1350.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1400.0', 'Origin_Code+=+NKG', 'Destination_Code+=+TAO'], ['Name+=+黄宗印', 'Origin+=+武汉', 'Ticket_Fee+=+450.0', 'Total_Fee+=+CNY500.', 'Origin_Code+=+WUE', 'Destination_Code+=+HPG'], ['Name+=+张展瑞', 'Flight_Number+=+HU7201', 'Flight_Date+=+08-03', 'Origin+=+天津', 'Destination+=+广州', 'Ticket_Fee+=+CNY', 'Ticket_Fee+=+2070.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+TSN', 'Destination_Code+=+CAN'], ['Name+=+CHEN', 'Flight_Number+=+CZ3630', 'Flight_Date+=+2019-04-09', 'Origin+=+GUANGZHOU', 'Destination+=+BANGKOK', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Origin_Code+=+CAN', 'Destination_Code+=+BKK'], ['Name+=+李先兵', 'Flight_Number+=+9H8309', 'Flight_Date+=+05-01', 'Origin+=+咸阳', 'Destination+=+大连', 'Ticket_Fee+=+CNY530.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY580.0', 'Origin_Code+=+XY', 'Destination_Code+=+DLC'], ['Name+=+WANG/PENG', 'Flight_Number+=+C78076', 'Flight_Date+=+201', 'Destination+=+武汉', 'Ticket_Fee+=+400', 'Origin_Code+=+HPG', 'Origin_Code+=+HP'], ['Name+=+沈广华', 'Flight_Number+=+CZ6662', 'Flight_Date+=+2019-0213', 'Origin+=+乌鲁木齐', 'Destination+=+义乌', 'Ticket_Fee+=+0.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+50.0', 'Origin_Code+=+URC', 'Destination_Code+=+YIW'], ['Flight_Date+=+2019-04-27', 'Origin+=+西安', 'Destination+=+广州', 'Ticket_Fee+=+930.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+960.', 'Origin_Code+=+XIY', 'Destination_Code+=+CAN'], ['Name+=+杨凤', 'Flight_Number+=+CZ8076', 'Destination+=+武汉', 'Develop_Fee+=+0.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+L/LIQUAN', 'Flight_Date+=+03-14', 'Destination+=+武汉', 'Ticket_Fee+=+490.0', 'Develop_Fee+=+5', 'Oil_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+GHP', 'Destination_Code+=+WUH'], ['Name+=+冯杰', 'Flight_Date+=+07-15', 'Origin+=+深圳', 'Destination+=+天津', 'Ticket_Fee+=+2110.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2160.0', 'Origin_Code+=+SZX', 'Destination_Code+=+TSN'], ['Flight_Number+=+J05175', 'Flight_Date+=+U017', 'Origin+=+三亚', 'Destination+=+西安', 'Ticket_Fee+=+800.00', 'Develop_Fee+=+50:00', 'Oil_Fee+=+0', 'Total_Fee+=+850.00', 'Origin_Code+=+SYK', 'Destination_Code+=+XIY'], ['Name+=+芦士埠', 'Flight_Number+=+CZ3108', 'Flight_Date+=+05-18', 'Origin+=+北京首', 'Origin+=+北京', 'Destination+=+广州白云', 'Destination+=+广州', 'Ticket_Fee+=+2310.0', 'Origin_Code+=+PEK', 'Destination_Code+=+CAN'], ['Flight_Number+=+CZ3966', 'Origin+=+上海虹桥', 'Destination+=+深圳', 'Develop_Fee+=+CNY.50.0', 'Oil_Fee+=+270.0', 'Total_Fee+=+61280.0', 'Origin_Code+=+SHA', 'Origin_Code+=+SZX'], ['Name+=+张永朝', 'Flight_Number+=+GS6633', 'Flight_Date+=+09-02', 'Origin+=+呼和浩特', 'Destination+=+沈阳', 'Ticket_Fee+=+680.0', 'Develop_Fee+=+50', 'Origin_Code+=+HET', 'Destination_Code+=+SHE'], ['Name+=+李平', 'Flight_Date+=+08-28', 'Origin+=+郑州', 'Destination+=+三亚', 'Ticket_Fee+=+2050.0', 'Oil_Fee+=+0.0', 'Oil_Fee+=+30.0', 'Total_Fee+=+CNY2110.0', 'Origin_Code+=+CGO', 'Destination_Code+=+SYX'], ['Name+=+罗小晶', 'Flight_Number+=+CZ3104', 'Flight_Date+=+2019-0419', 'Origin+=+北京', 'Destination+=+广州', 'Ticket_Fee+=+1160.0', 'Total_Fee+=+1210.0', 'Origin_Code+=+PEK', 'Destination_Code+=+CAN'], ['Name+=+彭俊', 'Flight_Date+=+09-25', 'Origin+=+遵义', 'Destination+=+广州', 'Ticket_Fee+=+5验0', 'Develop_Fee+=+50.0', 'Other_Fee+=+0.O', 'Total_Fee+=+550.0', 'Origin_Code+=+ZY', 'Destination_Code+=+CAN'], ['Name+=+黄梓舒', 'Flight_Number+=+7624', 'Flight_Date+=+07-23', 'Destination+=+北京', 'Ticket_Fee+=+630.0', 'Oil_Fee+=+10.', 'Other_Fee+=+0.0', 'Total_Fee+=+690.0', 'Origin_Code+=+DOY', 'Destination_Code+=+PEK'], ['Name+=+张旭', 'Flight_Number+=+9H6007', 'Flight_Date+=+03-18', 'Origin+=+咸阳', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+800.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+850.0', 'Origin_Code+=+XIY', 'Destination_Code+=+URC'], ['Name+=+ZHANG/SHUHUA', 'Flight_Number+=+G52654', 'Flight_Date+=+05-31', 'Destination+=+重庆', 'Ticket_Fee+=+660.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+660.0', 'Origin_Code+=+HCJ', 'Destination_Code+=+CKG'], ['Name+=+TIAN/ZHUORONG', 'Flight_Date+=+05-06', 'Destination+=+重庆', 'Ticket_Fee+=+1200.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1200.', 'Origin_Code+=+LLB', 'Destination_Code+=+CKC'], ['Name+=+吴昊阳', 'Flight_Number+=+3U8432', 'Flight_Date+=+04-27', 'Origin+=+三亚', 'Destination+=+常州', 'Ticket_Fee+=+2060.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY2110.0', 'Origin_Code+=+SYX', 'Destination_Code+=+CZX'], ['Name+=+米红萍', 'Flight_Number+=+CZ3940', 'Flight_Date+=+11-25', 'Origin+=+郑州', 'Destination+=+杭州', 'Destination+=+通明', 'Ticket_Fee+=+660.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+760.0', 'Origin_Code+=+CGO', 'Destination_Code+=+HGH'], ['Name+=+易福军', 'Flight_Number+=+G52654', 'Flight_Date+=+07-10', 'Destination+=+桂林', 'Ticket_Fee+=+180.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Total_Fee+=+180.0', 'Origin_Code+=+HCHC', 'Destination_Code+=+KWL'], ['Name+=+陈方家', 'Flight_Number+=+CZ332', 'Flight_Date+=+02-20', 'Origin+=+长沙', 'Destination+=+广州', 'Ticket_Fee+=+1280', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+O.0', 'Total_Fee+=+330.0', 'Origin_Code+=+CSX', 'Destination_Code+=+CAN'], ['Name+=+曹盼', 'Flight_Number+=+KY', 'Origin+=+腾冲', 'Destination+=+昆明', 'Ticket_Fee+=+1260.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1310.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG'], ['Name+=+赵建杰', 'Flight_Number+=+1074', 'Flight_Number+=+HO1074', 'Flight_Number+=+1074', 'Flight_Number+=+HO1074', 'Flight_Date+=+03-08', 'Origin+=+武汉', 'Destination+=+上海浦东', 'Ticket_Fee+=+CNY530.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY580.0', 'Origin_Code+=+WUH', 'Destination_Code+=+PVG'], ['Name+=+LU/BAIYU', 'Flight_Number+=+G52694', 'Flight_Date+=+04-16', 'Origin+=+HCJ', 'Destination+=+贵阳', 'Ticket_Fee+=+C', 'Ticket_Fee+=+220.', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY220.0', 'Destination_Code+=+KWE'], ['Name+=+YANG/MING', 'Origin+=+桂林', 'Destination+=+昆明', 'Develop_Fee+=+5O.', 'Other_Fee+=+0.0', 'Total_Fee+=+粥', 'Total_Fee+=+90.0', 'Origin_Code+=+KWL', 'Destination_Code+=+KMG'], ['Name+=+黄朝枝', 'Flight_Date+=+04-10', 'Origin+=+沈阳', 'Ticket_Fee+=+CNY1010.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1060.0', 'Origin_Code+=+SHE', 'Destination_Code+=+RIZ'], ['Name+=+詹吉泉', 'Flight_Number+=+C23538', 'Flight_Date+=+2019-0-12', 'Origin+=+上海虹桥', 'Destination+=+广州', 'Destination+=+上海虹桥', 'Ticket_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+16Z.0', 'Total_Fee+=+162.0', 'Origin_Code+=+SHA', 'Destination_Code+=+CAN'], ['Flight_Date+=+2019-04-08', 'Destination+=+普吉', 'Ticket_Fee+=+476', 'Ticket_Fee+=+1000', 'Other_Fee+=+10', 'Total_Fee+=+1576', 'Destination_Code+=+HKT'], ['Name+=+余昌全', 'Flight_Number+=+TV988', 'Flight_Date+=+04-24', 'Origin+=+成都', 'Destination+=+拉萨', 'Ticket_Fee+=+1380.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1430.', 'Origin_Code+=+CTU', 'Destination_Code+=+LXA'], ['Name+=+LIANG/HUIBIN', 'Flight_Number+=+CZ8076', 'Flight_Date+=+05-09', 'Destination+=+武汉', 'Ticket_Fee+=+CNY490.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+钱琳', 'Flight_Number+=+HU7414', 'Flight_Date+=+05-16', 'Origin+=+太原', 'Destination+=+兰州', 'Ticket_Fee+=+CNY860.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY910.0', 'Origin_Code+=+TYN', 'Destination_Code+=+LHW'], ['Name+=+LAI/MINGJIE', 'Flight_Number+=+3U8626', 'Flight_Date+=+04-13', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+YDC', 'Destination_Code+=+DG', 'Destination_Code+=+XY'], ['Name+=+FANG/MIAO', 'Destination+=+晋江', 'Ticket_Fee+=+1240.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1290.', 'Origin_Code+=+LLF', 'Destination_Code+=+JN'], ['Name+=+DU/QIUE', 'Flight_Number+=+HU7935', 'Flight_Date+=+09-18', 'Origin+=+海口', 'Destination+=+澳门', 'Ticket_Fee+=+314.0', 'Total_Fee+=+11.7', 'Origin_Code+=+HAK', 'Destination_Code+=+MFM'], ['Name+=+ZHANG/SIRUI', 'Flight_Number+=+3U8925', 'Flight_Number+=+3U89', 'Flight_Number+=+3U8925', 'Flight_Date+=+07-15', 'Origin+=+成都', 'Destination+=+普吉', 'Develop_Fee+=+300.0', 'Oil_Fee+=+8.0', 'Other_Fee+=+421.0', 'Origin_Code+=+CTU', 'Destination_Code+=+HKT'], ['Name+=+王琼秀', 'Flight_Number+=+CZ5145', 'Flight_Date+=+2018-09-29', 'Origin+=+南京', 'Destination+=+西安', 'Ticket_Fee+=+CNY760.0', 'Develop_Fee+=+CNY500', 'Oil_Fee+=+10.0', 'Total_Fee+=+CNY820.0', 'Origin_Code+=+NKG', 'Destination_Code+=+XIY'], ['Name+=+李瑜', 'Flight_Date+=+05-27', 'Origin+=+达县', 'Destination+=+深圳', 'Ticket_Fee+=+1430.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1480.0', 'Origin_Code+=+DAX', 'Destination_Code+=+SZX'], ['Name+=+张志兵', 'Flight_Number+=+1816', 'Flight_Date+=+10-18', 'Origin+=+厦门', 'Destination+=+北京', 'Ticket_Fee+=+120.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+2170.', 'Origin_Code+=+XMN', 'Destination_Code+=+PEK'], ['Name+=+李伟挺', 'Flight_Number+=+7066', 'Flight_Number+=+HU7066', 'Flight_Number+=+7066', 'Flight_Number+=+HU7066', 'Flight_Date+=+12-29', 'Origin+=+厦门', 'Destination+=+深圳', 'Ticket_Fee+=+1300.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1350.', 'Origin_Code+=+XMN', 'Destination_Code+=+SZX'], ['Name+=+XU/XAOJING', 'Flight_Number+=+CZ8076', 'Flight_Number+=+7', 'Flight_Number+=+CZ8076', 'Flight_Number+=+7', 'Flight_Date+=+03-14', 'Destination+=+重庆', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HPG', 'Origin_Code+=+HPC', 'Destination_Code+=+CKG'], ['Name+=+刘伯隆', 'Flight_Number+=+1010', 'Flight_Date+=+07-02', 'Destination+=+咸阳', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+50', 'Oil_Fee+=+0.0', 'Other_Fee+=+164.0', 'Total_Fee+=+174.0', 'Origin_Code+=+GYU', 'Destination_Code+=+XY'], ['Name+=+TIAN/ZHUORONG', 'Flight_Date+=+05-06', 'Destination+=+重庆', 'Ticket_Fee+=+1200.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1200.', 'Origin_Code+=+LLB', 'Destination_Code+=+CKC'], ['Name+=+HUANG/JIAOXING', 'Flight_Number+=+CA4464', 'Flight_Date+=+05-13', 'Destination+=+成都', 'Ticket_Fee+=+1320.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1370.0', 'Origin_Code+=+PZI', 'Destination_Code+=+GNU'], ['Name+=+材东', 'Flight_Number+=+CZ9381', 'Flight_Date+=+2019-05-17', 'Origin+=+上海浦东', 'Destination+=+武汉', 'Ticket_Fee+=+2060.0', 'Develop_Fee+=+500', 'Oil_Fee+=+0', 'Total_Fee+=+60.2110.0', 'Origin_Code+=+PVG', 'Origin_Code+=+FIG', 'Destination_Code+=+WUH'], ['Name+=+孙小俊', 'Flight_Number+=+5608', 'Flight_Date+=+05-28', 'Origin+=+淮安', 'Destination+=+上海浦东', 'Ticket_Fee+=+510.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+560.0', 'Origin_Code+=+HIA', 'Destination_Code+=+PVG'], ['Name+=+LIU/HAIRONG', 'Flight_Number+=+G5254', 'Flight_Number+=+G', 'Flight_Number+=+G5254', 'Flight_Date+=+05-10', 'Destination+=+重庆', 'Ticket_Fee+=+750.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY750.0', 'Origin_Code+=+JHC', 'Destination_Code+=+CKG'], ['Name+=+许宸宇(童票)', 'Flight_Number+=+8133', 'Flight_Number+=+MF8133', 'Flight_Number+=+8133', 'Flight_Number+=+MF8133', 'Flight_Date+=+07-31', 'Origin+=+厦门', 'Destination+=+天津', 'Ticket_Fee+=+CNY700.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY700.0', 'Origin_Code+=+XMN', 'Destination_Code+=+TSN'], ['Name+=+张冬晨', 'Flight_Number+=+CZ3114', 'Flight_Number+=+C', 'Flight_Number+=+CZ3114', 'Flight_Date+=+07-22', 'Origin+=+北京', 'Destination+=+广州', 'Ticket_Fee+=+2640.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+0.0', 'Origin_Code+=+PEK', 'Destination_Code+=+CAN'], ['Name+=+陈朝', 'Flight_Date+=+07-13', 'Origin+=+昆明', 'Destination+=+郑州', 'Ticket_Fee+=+7010', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+810.0', 'Origin_Code+=+KMG', 'Destination_Code+=+CGO'], ['Name+=+方义锋', 'Flight_Number+=+CA8906', 'Flight_Date+=+10-21', 'Origin+=+北京', 'Destination+=+大连', 'Ticket_Fee+=+1120.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1170.0', 'Origin_Code+=+PEK', 'Destination_Code+=+DLC'], ['Name+=+李丹', 'Flight_Number+=+ZH8310', 'Flight_Date+=+01-14', 'Origin+=+襄樊', 'Destination+=+珠海', 'Ticket_Fee+=+880.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+930.0', 'Origin_Code+=+XFN', 'Destination_Code+=+ZUH'], ['Name+=+赵建杰', 'Flight_Number+=+JR1527', 'Flight_Date+=+02-05', 'Origin+=+武汉', 'Destination+=+襄樊', 'Ticket_Fee+=+CNY350.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY350.0', 'Origin_Code+=+WUH', 'Destination_Code+=+XFN'], ['Name+=+钱琳', 'Flight_Number+=+9530', 'Flight_Date+=+03-21', 'Origin+=+温州', 'Destination+=+上海浦东', 'Ticket_Fee+=+550.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+600.0', 'Origin_Code+=+WN', 'Destination_Code+=+PVG'], ['Name+=+陈贤锋', 'Flight_Number+=+5454', 'Flight_Date+=+10-29', 'Origin+=+昆明', 'Destination+=+宁波', 'Ticket_Fee+=+1160.0', 'Develop_Fee+=+CN50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1210.0', 'Origin_Code+=+KMG', 'Destination_Code+=+NGB'], ['Name+=+ZHANG/SHUAI', 'Flight_Number+=+CZ8076', 'Flight_Date+=+05-20', 'Ticket_Fee+=+武汉', 'Ticket_Fee+=+404', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HPG', 'Origin_Code+=+HPC', 'Destination_Code+=+WUH'], ['Name+=+冯杰', 'Flight_Number+=+1083', 'Flight_Date+=+06-19', 'Origin+=+杭州', 'Destination+=+西宁', 'Ticket_Fee+=+1450.0', 'Total_Fee+=+C', 'Total_Fee+=+1500.0', 'Origin_Code+=+HGH', 'Destination_Code+=+XNN'], ['Name+=+许涛涛', 'Flight_Number+=+CZ3464', 'Origin+=+重庆', 'Destination+=+广州', 'Develop_Fee+=+50.0', 'Oil_Fee+=+30.0', 'Other_Fee+=+0.0', 'Total_Fee+=+310.0', 'Origin_Code+=+CKG', 'Destination_Code+=+CAN'], ['Name+=+WAN/SHUNQUIANG', 'Flight_Date+=+03-20', 'Destination+=+武汉', 'Ticket_Fee+=+420.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+470.0', 'Origin_Code+=+HPG', 'Destination_Code+=+WUH'], ['Name+=+CHEN/PENG', 'Flight_Number+=+2966', 'Flight_Date+=+06-', 'Origin+=+珠海', 'Destination+=+长沙', 'Ticket_Fee+=+370.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+420.', 'Origin_Code+=+ZUH', 'Destination_Code+=+CSX'], ['Name+=+蔡品伦', 'Flight_Number+=+CZ3306', 'Flight_Date+=+03-04', 'Origin+=+宁波', 'Destination+=+南宁', 'Ticket_Fee+=+CNY1660.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.0', 'Total_Fee+=+CNY1710.0', 'Origin_Code+=+NGE', 'Destination_Code+=+NNG'], ['Name+=+杭定', 'Flight_Number+=+8L9911', 'Flight_Date+=+04-02', 'Origin+=+曼浊', 'Destination+=+是明', 'Ticket_Fee+=+770.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+820.0', 'Origin_Code+=+JHC', 'Destination_Code+=+KMG'], ['Name+=+侯光泰', 'Flight_Number+=+705', 'Flight_Date+=+11-06', 'Origin+=+深圳', 'Destination+=+上海虹桥', 'Ticket_Fee+=+1540.0', 'Oil_Fee+=+50.0', 'Other_Fee+=+0.0', 'Total_Fee+=+1640.0', 'Origin_Code+=+SZX', 'Destination_Code+=+SHA'], ['Name+=+王梓瑜(儿童票)', 'Flight_Number+=+MF8086', 'Flight_Date+=+08-01', 'Origin+=+大连', 'Destination+=+南京', 'Ticket_Fee+=+500.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+500.0', 'Origin_Code+=+DLC', 'Destination_Code+=+NKG'], ['Name+=+吴年娇', 'Flight_Number+=+MU5666', 'Flight_Date+=+08-08', 'Origin+=+厦门', 'Destination+=+上海虹桥', 'Ticket_Fee+=+1660.0', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+CNY1710.', 'Origin_Code+=+XMN', 'Destination_Code+=+SHA'], ['Name+=+陈露', 'Flight_Number+=+CZ3582', 'Flight_Date+=+07-19', 'Origin+=+上海虹桥', 'Destination+=+广州', 'Ticket_Fee+=+14605', 'Develop_Fee+=+50.0', 'Oil_Fee+=+O.0', 'Other_Fee+=+O.0', 'Total_Fee+=+510.0', 'Origin_Code+=+SHA', 'Destination_Code+=+CAN'], ['Name+=+GCHEN/LIN', 'Flight_Number+=+CJ93', 'Flight_Date+=+20196-04', 'Destination+=+惠州', 'Ticket_Fee+=+520.00', 'Total_Fee+=+520.00', 'Origin_Code+=+HCJ'], ['Name+=+王梓瑜(儿童票)', 'Flight_Number+=+MF8086', 'Flight_Date+=+08-01', 'Origin+=+大连', 'Destination+=+南京', 'Ticket_Fee+=+500.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+500.0', 'Origin_Code+=+DLC', 'Destination_Code+=+NKG'], ['Name+=+陈春明', 'Flight_Number+=+Z6960', 'Flight_Date+=+06-25', 'Origin+=+咸阳', 'Destination+=+乌鲁木齐', 'Ticket_Fee+=+CNY7010', 'Develop_Fee+=+50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+O.0', 'Total_Fee+=+830.0', 'Origin_Code+=+XIY', 'Destination_Code+=+URC'], ['Name+=+沙黄辉', 'Flight_Number+=+5244', 'Flight_Date+=+08-22', 'Origin+=+宁波', 'Destination+=+青岛', 'Ticket_Fee+=+CNY810.0', 'Develop_Fee+=+CNYCN50.0', 'Oil_Fee+=+10.0', 'Other_Fee+=+0.0', 'Total_Fee+=+870.0', 'Origin_Code+=+NGB', 'Destination_Code+=+TAO'], ['Name+=+HOU/HAIRONGMS', 'Flight_Number+=+SC8885', 'Flight_Date+=+01-17', 'Origin+=+昆明', 'Destination+=+曼谷', 'Develop_Fee+=+90.0', 'Oil_Fee+=+200', 'Other_Fee+=+340.0', 'Origin_Code+=+KMG', 'Destination_Code+=+BKK'], ['Name+=+CHANG/JIALI', 'Flight_Number+=+MU5954', 'Flight_Date+=+06-28', 'Origin+=+腾冲', 'Destination+=+昆明', 'Ticket_Fee+=+1520.0', 'Develop_Fee+=+0.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1570.0', 'Origin_Code+=+TCZ', 'Destination_Code+=+KMG'], ['Name+=+杨会贤', 'Flight_Date+=+18-01', 'Origin+=+南阳', 'Destination+=+深圳', 'Ticket_Fee+=+1验', 'Develop_Fee+=+50.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Total_Fee+=+380.0', 'Origin_Code+=+NNY', 'Destination_Code+=+SZX'], ['Name+=+李嘉培', 'Flight_Number+=+9428', 'Flight_Date+=+04-26', 'Origin+=+重庆', 'Destination+=+深圳', 'Ticket_Fee+=+290.0', 'Develop_Fee+=+0', 'Oil_Fee+=+0.0', 'Total_Fee+=+1340.0', 'Origin_Code+=+CKG', 'Destination_Code+=+SZX'], ['Name+=+杨璇', 'Flight_Number+=+CZ6', 'Flight_Date+=+05-25', 'Origin+=+乌鲁木齐', 'Destination+=+石家庄', 'Ticket_Fee+=+CNY1020.0', 'Develop_Fee+=+50.O', 'Oil_Fee+=+0.0', 'Other_Fee+=+O.O', 'Origin_Code+=+UR', 'Destination_Code+=+SJW'], ['Name+=+叶秋慧', 'Flight_Number+=+GJ8759', 'Flight_Date+=+09-02', 'Origin+=+杭州', 'Destination+=+兰州', 'Ticket_Fee+=+CNY1930.0', 'Oil_Fee+=+0.0', 'Other_Fee+=+0.0', 'Origin_Code+=+HGH', 'Destination_Code+=+LHW'], ['Name+=+黄智艺', 'Flight_Date+=+01-06', 'Origin+=+WMTWM', 'Destination+=+福州', 'Ticket_Fee+=+570.0', 'Other_Fee+=+0.0', 'Total_Fee+=+CNY620.', 'Destination_Code+=+FOC'], ['Name+=+任玉柱', 'Flight_Number+=+MU2159', 'Flight_Date+=+11-12', 'Origin+=+延安', 'Ticket_Fee+=+咸阳', 'Ticket_Fee+=+100.0', 'Oil_Fee+=+0.0', 'Total_Fee+=+170.', 'Origin_Code+=+ENY', 'Destination_Code+=+XIY']]
entity_lls2 == entity_lls1
# Out:
# False

# %%
print(set(entity_lls2[0]))
# Out:
# {'Total_Fee+=+1830.00', 'Origin+=+HPG', 'Destination+=+上海浦东', 'Develop_Fee+=+40.00', 'Flight_Number+=+MU537', 'Name+=+QIN/FEL', 'Flight_Number+=+FM84', 'Ticket_Fee+=+1200.00', 'Destination+=+曼谷口', 'Origin_Code+=+HPGT', 'Flight_Date+=+24JUN', 'Destination+=+中院'}

# %%
print(set(entity_lls1[0])&set(entity_lls2[0]))
# Out:
# {'Total_Fee+=+1830.00', 'Origin+=+HPG', 'Destination+=+上海浦东', 'Develop_Fee+=+40.00', 'Flight_Number+=+MU537', 'Name+=+QIN/FEL', 'Flight_Number+=+FM84', 'Ticket_Fee+=+1200.00', 'Destination+=+曼谷口', 'Origin_Code+=+HPGT', 'Destination+=+中院'}

# %%
for ind, (ele1, ele2) in enumerate(zip(entity_lls1, entity_lls2)):
    if set(ele1) != set(ele2):
        print(ind)
# Out:
# 0
# 7
# 14
# 15
# 26
# 27
# 37
# 39
# 43
# 44
# 55
# 61
# 63
# 68
# 73
# 75
# 89
# 96
# 97
# 104
# 105
# 120
# 127
# 133
# 135
# 138
# 140
# 144
# 145
# 157
# 159
# 165
# 166
# 168
# 169
# 171
# 176
# 179
# 185
# 201
# 206
# 207
# 211
# 213
# 219
# 224
# 228
# 231
# 233
